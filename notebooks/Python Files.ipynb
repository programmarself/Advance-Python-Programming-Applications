# %% [markdown]
# Python Files

# %% [markdown]
# ![image.png](attachment:9f6899a9-fc03-4fc7-a084-adab4723038d.png)
# Python provides various functions to perform different file operations, a process known as File Handling.

# %% [markdown]
# ![image.png](attachment:9c5490b4-7bb8-4f46-846e-b3baeada24a1.png)

# %% [markdown]
# ![image.png](attachment:a6832559-aa60-4601-a81a-21efe66631d7.png)
# ![image.png](attachment:e2e67a84-6b9b-4ef8-a07c-1e268683f84e.png)
# ![image.png](attachment:b5bdda91-440d-4ce1-9b63-a341b85ce439.png)

# %% [markdown]
# ![image.png](attachment:eb761ff6-8474-451f-bd01-3835a91447f3.png)

# %%
#Here are a few examples of opening a file in different modes,

# open a file in default mode (read and text)
#file1 = open("test.txt")      # equivalent to open("test.txt", "r")

# open a file in write and text mode 
f = open("test.txt",'w')  

# open a file in read, write and binary mode
#file1 = open("img.bmp",'+b')

# %%
f.write('my name is Ihsan1\n')
f.write('my name is Ihsan2\n')
f.close()

# %%
file1 = open("test.txt")
print(file1.read())
# Out:
# my name is Ihsan1
# my name is Ihsan2

# %%
#Opening a File Using its Full Path
#We can also open a file using its full path.

file_path = 'D:/BS_work/Spring 2023_Database/All Oracle SQL lectures/notes-generated-spool/notesup.txt'
f = open(file_path)
print(f.read())
# Out:
# SQL> select * from emp where job='MANAGER' and deptno=20 and sal>=2000;
#
#      EMPNO ENAME      JOB              MGR HIREDATE         SAL       COMM     DEPTNO
# ---------- ---------- --------- ---------- --------- ---------- ---------- ----------
#       7566 JONES      MANAGER         7839 02-APR-81       2975                    20
#
# SQL> select * from emp;
#
#      EMPNO ENAME      JOB              MGR HIREDATE         SAL       COMM     DEPTNO
# ---------- ---------- --------- ---------- --------- ---------- ---------- ----------
#       7369 SMITH      CLERK           7902 17-DEC-80        800                    20
#       7499 ALLEN      SALESMAN        7698 20-FEB-81       1600        300         30
#       7521 WARD       SALESMAN        7698 22-FEB-81       1250        500         30
#       7566 JONES      MANAGER         7839 02-APR-81       2975                    20
#       7654 MARTIN     SALESMAN        7698 28-SEP-81       1250       1400         30
# ...

# %%
file_path = 'D:\\BS_work\\Spring 2023_Database\\All Oracle SQL lectures\\notes-generated-spool\\notesup.txt'
f = open(file_path)
print(f.read())
# Out:
# SQL> select * from emp where job='MANAGER' and deptno=20 and sal>=2000;
#
#      EMPNO ENAME      JOB              MGR HIREDATE         SAL       COMM     DEPTNO
# ---------- ---------- --------- ---------- --------- ---------- ---------- ----------
#       7566 JONES      MANAGER         7839 02-APR-81       2975                    20
#
# SQL> select * from emp;
#
#      EMPNO ENAME      JOB              MGR HIREDATE         SAL       COMM     DEPTNO
# ---------- ---------- --------- ---------- --------- ---------- ---------- ----------
#       7369 SMITH      CLERK           7902 17-DEC-80        800                    20
#       7499 ALLEN      SALESMAN        7698 20-FEB-81       1600        300         30
#       7521 WARD       SALESMAN        7698 22-FEB-81       1250        500         30
#       7566 JONES      MANAGER         7839 02-APR-81       2975                    20
#       7654 MARTIN     SALESMAN        7698 28-SEP-81       1250       1400         30
# ...

# %%
f=open('waqas.txt','w')
f.write('I am Sick\n')
f.write('My mood off\n,')
f.write('I am tired\n')
f.write('I am hungry')
f.close()

# %%
f=open('waqas.txt','r')
print(f.read())
f.close()
# Out:
# I am Sick
# My mood off,I am tired,I am hungry

# %%
#Writing to Files in Python
#To write to a Python file, we need to open it in write mode using the w parameter.
#Be Careful While Writing to a File
#If we try to perform the write operation to a file that already has some content, the new content will replace the existing ones. For example,

f= open('atif.txt','w') #his function returns a file object, which you can use to perform operations on the file.
f.write('Today we will start python file handling\n') # write a line to the file
f.write('try except clause in exception\n')
f.write('else and finally block in exception\n')
f.close() 
#Note: Closing a file will free up the resources that are tied to the file. Hence, it is a good programming practice to always close the file.

# %%
f= open('atif.txt','r')
print(f.readline())
print(f.readline())
print(f.readline())
f.close()
# Out:
# Today we will start python file handling
#
# try except clause in exception
#
# else and finally block in exception

# %%
f= open('waqas.txt','r')
print(f.readline())
print(f.readline())
print(f.readline())
f.close()
# Out:
# I am Sick
#
# My mood off
#
# ,I am tired

# %%
# To append the data, you need to open the file in 'a' mode

f= open('atif.txt','a')
f.write('Some students have done their assignments\n') # write a line to the file
f.write('While others are still strugling to complete it\n')
f.write('Classses in exception\n')
f.close()

# %%
# Reading all data at once
f= open('atif.txt','r')
contents=f.read() # read entire content of file at once
print(contents)
f.close()
# Out:
# Today we will start python file handling
# try except clause in exception
# else and finally block in exception
# Some students have done their assignments
# While others are still strugling to complete it
# Classses in exception
# Some students have done their assignments
# While others are still strugling to complete it
# Classses in exception
# Some students have done their assignments
# While others are still strugling to complete it
# Classses in exception

# %%
# Reading all lines as an array
f= open('atif.txt','r')
contents=f.readlines() 
print(contents)
f.close()
# Out:
# ['Today we will start python file handling\n', 'try except clause in exception\n', 'else and finally block in exception\n', 'Some students have done their assignments\n', 'While others are still strugling to complete it\n', 'Classses in exception\n', 'Some students have done their assignments\n', 'While others are still strugling to complete it\n', 'Classses in exception\n', 'Some students have done their assignments\n', 'While others are still strugling to complete it\n', 'Classses in exception\n']

# %%
for line in contents:
    print(line)
# Out:
# Today we will start python file handling
#
# try except clause in exception
#
# else and finally block in exception
#
# Some students have done their assignments
#
# While others are still strugling to complete it
#
# Classses in exception
#
# Some students have done their assignments
#
# While others are still strugling to complete it
#
# Classses in exception
#
# Some students have done their assignments
#
# While others are still strugling to complete it
#
# Classses in exception

# %%
# Reading the first line or raading one line at a time
f= open('atif.txt','r')
print(f.readline() ) # The readline() method is called on the file object to read the first line from the file. This method reads up to the next newline character (\n) or the end of the file, and returns the line as a string. 
print(f.readline()) #The readline() method is called again on the file object to read the next line from the file. 
f.close()
# Out:
# Today we will start python exception
#
# try except clause in exception

# %%
# looping through the data using for loop
# we can iterate through the file using file pointer
f= open('atif.txt','r')
#print(type(f))

for text in f:
    print(text)
f.close()
# Out:
# Today we will start python file handling
#
# try except clause in exception
#
# else and finally block in exception
#
# Some students have done their assignments
#
# While others are still strugling to complete it
#
# Classses in exception
#
# Some students have done their assignments
#
# While others are still strugling to complete it
#
# Classses in exception
#
# Some students have done their assignments
#
# While others are still strugling to complete it
#
# Classses in exception

# %% [markdown]
# <b>Opening a Python File Using with...open</b><br>
# In Python, there is a better way to open a file using with...open. For example,<br>
# The code uses the with statement to open the file atif.txt in read mode ("r") and creates a file object (file1).<br>
# The with statement ensures that the file is automatically closed after the block of code inside the with statement is executed.
# <br>This is a good practice because it ensures that resources are properly managed.

# %%
#Here, with...open automatically closes the file, so we don't have to use the close() function.
with open("atif.txt", "r") as file1:
    read_content = file1.read()
    print(read_content)
# Out:
# Today we will start python file handling
# try except clause in exception
# else and finally block in exception
# Some students have done their assignments
# While others are still strugling to complete it
# Classses in exception
# Some students have done their assignments
# While others are still strugling to complete it
# Classses in exception

# %% [markdown]
# <b>Exception Handling in Files</b><br>
# If an exception occurs while working with a file, the code exists without closing the file. Hence, it's a good practice to use the try...finally block.

# %%
file1 = open("mubeen.txt", "r")
read_content = file1.read()
print(read_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 file1 = open("mubeen.txt", "r")
#       2 read_content = file1.read()
#       3 print(read_content)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mubeen.txt'

# %%
try:
    file1 = open("mubeen.txt", "r")
    read_content = file1.read()
    print(read_content)
    
except FileNotFoundError as e: #This exception occurs when the file or directory you are trying to open does not exist.
    print(f"Error: The file was not found. Details: {e}")
    
finally:
    # close the file
    print("hello")
    file1.close() #Here, the finally block is always executed, so we have kept the close() function inside it. This ensures that the file will always be closed.
# Out:
# Error: The file was not found. Details: [Errno 2] No such file or directory: 'mubeen.txt'
# hello

# %% [markdown]
# ![image.png](attachment:bc3cf08a-556e-4bbc-8a55-a82192236bc8.png)

# %% [markdown]
# The current_position obtained from file.tell() in Python indicates the current byte offset from the beginning of the file. In other words, it represents the current position of the file object's cursor or pointer within the file.
#
# When you open a file in a particular mode (e.g., read or write), a file object is created, and the file's internal cursor is positioned at the start of the file.
# As you read from or write to the file, the cursor moves forward within the file.
# When you call file.tell(), it returns the current byte offset of the cursor from the start of the file. This tells you the position in the file where the next read or write operation will occur.
# For example:
#
# If you read a certain number of bytes or lines from a file, file.tell() will give you the current position in bytes of where the next read operation will start.
# Similarly, if you write data to a file, file.tell() will provide the current position in bytes of where the next write operation will start.
# This information is useful for tracking the file object's position and for seeking back to a specific position in the file using file.seek() if necessary.
#
# File's beginning: The beginning of the file is the very start of the file, where the first byte of data is stored.
# Byte offset: An offset is a measure of distance, and in this context, it refers to the number of bytes from the start of the file to the current position. For instance, if you are at the beginning of the file, the byte offset is 0. As you read through the file, the byte offset increases.
# Current byte offset: This is the position of the file object's cursor at the moment you call tell(). It tells you where in the file the cursor is, in terms of bytes from the start of the file.
# So, when you use the tell() method and get a value, this value is the current byte offset from the beginning of the file. It indicates how many bytes you have read from the start of the file to reach the current position of the cursor. For example, if tell() returns 20, it means you are currently at the 20th byte from the start of the file.

# %%
# Open the file in read mode
with open("atif.txt", "r") as file:
    # Read the first line
    first_line = file.readline()
    print("First line:", first_line)
    
    # Get the current position of the file object
    current_position = file.tell()
    print("Current position in the file:", current_position)
    
    # Read the rest of the file
    rest_of_file = file.read()
    print("Rest of the file:", rest_of_file)
# Out:
# First line: Today we will start python file handling
#
# Current position in the file: 42
# Rest of the file: try except clause in exception
# else and finally block in exception
# Some students have done their assignments
# While others are still strugling to complete it
# Classses in exception

# %%
# Open the file in write mode
with open("output_file.txt", "w") as file:
    # Define a string to write to the file
    string_to_write = "This is a test string.\nthis is another test string.\n"
    
    # Write the string to the file
    file.write(string_to_write)
    
    print(f"'{string_to_write.strip()}' was written to the file.")
# Out:
# 'This is a test string.
# this is another test string.' was written to the file.

# %%
# Open the file in write mode
with open("output_file_lines.txt", "w") as file:
    # Define a list of lines to write to the file
    lines_to_write = [
        "Line 1: Hello, world!\n",
        "Line 2: This is a test.\n",
        "Line 3: Python is great.\n"
    ]
    
    # Write the list of lines to the file
    file.writelines(lines_to_write)
    
    print(f"{len(lines_to_write)} lines were written to the file.")
# Out:
# 3 lines were written to the file.

# %% [markdown]
# ![image.png](attachment:2f1341fd-f2a3-46a9-b470-ba19d284f6b5.png)
# ![image.png](attachment:0e825b4f-f0f7-4b66-bbe4-ec3d87a9cf7b.png)

# %% [markdown]
# import csv
# #Then, the csv.reader() is used to read the file, which returns an iterable reader object.
# #The reader object is then iterated using a for loop to print the contents of each row.
#
# with open('people.csv', 'r') as file: <br>
#     reader = csv.reader(file)
#
#     for row in reader:
#         print(row)

# %% [markdown]
# <b>Write to CSV Files with Python</b><br>
# The csv module provides the csv.writer() function to write to a CSV file.
#
# Let's look at an example.

# %%
# !pip install csv

# %%
import csv

# %%
#!pip install csv
import csv
with open('students.csv','r') as fg: # fg is refering to csv object
    rd= csv.reader(fg) # reader returns reader object--iterable
    for row in rd:
        print(row)
# Out:
# ['Student_name', 'CGPA']
# ['Farhan', '3.8']
# ['Iqrar', '3.8']
# ['Usman', '3.8']

# %%
import csv
with open('Navtac.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    #rites the header row with column names to the CSV file.
    writer.writerow(["SN", "Name", "Address"]) 
    #writes the first data row to the CSV file.
    writer.writerow([1, "ESSa", "Peshawar"])
    writer.writerow([2, "Iqrar", "Hangu"])
    writer.writerow([3, "fazal", "Swabi"])

# %%
import csv
with open('Navtac.csv','r') as fg: # fg is refering to csv object
    rd= csv.reader(fg) # reader returns reader object--iterable
    for row in rd:
        print(row)
# Out:
# ['SN', 'Name', 'Address']
# ['1', 'ESSa', 'Peshawar']
# ['2', 'Iqrar', 'Hangu']
# ['3', 'fazal', 'Swabi']

# %% [markdown]
# ![image.png](attachment:daff2fe7-4c62-4351-b553-c643c978310e.png)

# %%
import csv
#we have opened the innovators.csv file in writing mode using open() function.
#newline='':
#The newline parameter is set to an empty string ('').
#This parameter is important when writing to a CSV file in Python. It ensures that the writer does not inadvertently add extra newline characters to the file. Without setting newline='', 
#you may encounter issues such as extra blank lines being added when writing rows to the CSV file.

with open('innovators.csv', 'w', newline='') as file:
    #Next, the csv.writer() function is used to create a writer object. 
    writer = csv.writer(file)

    #The writer.writerow() function is then used to write single rows to the CSV file.
    writer.writerow(["SN", "Name", "Contribution"])

    writer.writerow([1, "Linus Torvalds", "Linux Kernel"])
    writer.writerow([2, "Tim Berners-Lee", "World Wide Web"])
    writer.writerow([3, "Guido van Rossum", "Python Programming"])

# %% [markdown]
# <b>Writing Multiple Rows with writerows()<b><br>
# If we need to write the contents of the 2-dimensional list to a CSV file, here's how we can do it.

# %%
#If we need to write the contents of the 2-dimensional list to a CSV file, here's how we can do it.
import csv
row_list = [["SN", "Name", "Contribution"],
             [1, "Linus Torvalds", "Linux Kernel"],
             [2, "Tim Berners-Lee", "World Wide Web"],
             [3, "Guido van Rossum", "Python Programming"]]
with open('employees.csv', 'w', newline='') as file:
      w=csv.writer(file)
      w.writerows(row_list)

# %%
with open('employees.csv', 'r') as file:
      reader=csv.reader(file)
      for row in reader:
          print(';'.join(row))
# Out:
# SN;Name;Contribution
# 1;Linus Torvalds;Linux Kernel
# 2;Tim Berners-Lee;World Wide Web
# 3;Guido van Rossum;Python Programming

# %% [markdown]
# ![image.png](attachment:fd64598b-f852-40fe-aa95-5a803bf008e8.png)

# %%
#Write CSV File Having Pipe Delimiter
import csv
data_list = [["SN", "Name", "Contribution"],
             [1, "Linus Torvalds", "Linux Kernel"],
             [2, "Tim Berners-Lee", "World Wide Web"],
             [3, "Guido van Rossum", "Python Programming"]]

with open('innovators_pipe.csv', 'w', newline='') as file:
    
    writer = csv.writer(file, delimiter='|')
    writer.writerows(data_list)

# %%
with open('innovators_pipe.csv', 'r') as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['SN|Name|Contribution']
# ['1|Linus Torvalds|Linux Kernel']
# ['2|Tim Berners-Lee|World Wide Web']
# ['3|Guido van Rossum|Python Programming']

# %% [markdown]
# ![image.png](attachment:83aef73e-270c-491c-ab0c-a87d5e55f1f4.png)
# ![image.png](attachment:37b379ae-b190-4517-9d51-e53dd75ebb87.png)

# %%
#Write CSV files with quotes
import csv
row_list = [
    ["SN", "Name", "Profession"],
    [1, "Iqrar", "Manager"],
    [2, "Uzair Khan", "CEO Google"],
    [3, "Asnad", "CEO Tesla"]
]
with open('quotes.csv', 'w', newline='') as file:
    writer = csv.writer(file, quoting=csv.QUOTE_NONNUMERIC, delimiter=';')
    writer.writerows(row_list)

# %%
with open('quotes.csv', 'r') as file:
    reader = csv.reader(file, quoting=csv.QUOTE_NONNUMERIC, delimiter=";")

    for row in reader:
        print(row)
# Out:
# ['SN', 'Name', 'Profession']
# [1.0, 'Iqrar', 'Manager']
# [2.0, 'Uzair Khan', 'CEO Google']
# [3.0, 'Asnad', 'CEO Tesla']

# %%
#Read CSV files with quotes
import csv
with open('quotesdf.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['SN', ' "Name"', ' "Quotes"']
# ['1', ' Buddha', ' "What we think we become"']
# ['2', ' Mark Twain', ' "Never regret anything that made you smile"']
# ['3', ' Oscar Wilde', ' "Be yourself everyone else is already taken"']

# %%
#Read CSV files with quotes
import csv
with open('quotesdf.csv', 'r') as file:
    reader = csv.reader(file,  skipinitialspace=True)
    for row in reader:
        print(row)
# Out:
# ['SN', 'Name', 'Quotes']
# ['1', 'Buddha', 'What we think we become']
# ['2', 'Mark Twain', 'Never regret anything that made you smile']
# ['3', 'Oscar Wilde', 'Be yourself everyone else is already taken']

# %%
#Read CSV files with quotes
import csv
with open('quotesdf.csv', 'r') as file:
#we have passed csv.QUOTE_ALL to the quoting parameter. It is a constant defined by the csv module.
#csv.QUOTE_ALL specifies the reader object that all the values in the CSV file are present inside quotation marks.

csv.QUOTE_ALL specifies the reader object that all the values in the CSV file are present inside quotation marks.
    reader = csv.reader(file, quoting=csv.QUOTE_ALL, skipinitialspace=True)
    for row in reader:
        print(row)
# Out:
# ['SN', 'Name', 'Quotes']
# ['1', 'Buddha', 'What we think we become']
# ['2', 'Mark Twain', 'Never regret anything that made you smile']
# ['3', 'Oscar Wilde', 'Be yourself everyone else is already taken']

# %%
with open('quotes.csv', 'r', newline='') as file:
    reader = csv.reader(file, quoting=csv.QUOTE_NONNUMERIC, delimiter=';')
    for row in reader:
        # Convert each row list to a string and print it
        print(";".join([str(field) for field in row]))
# Out:
# SN;Name;Quotes
# 1.0;Buddha;What we think we become
# 2.0;Mark Twain;Never regret anything that made you smile
# 3.0;Oscar Wilde;Be yourself everyone else is already taken

# %%
#Write CSV files without quotes
import csv
row_list = [
    ["SN", "Name", "Quotes"],
    [1, "Buddha", "What we think we become"],
    [2, "Mark Twain", "Never regret anything that made you smile"],
    [3, "Oscar Wilde", "Be yourself everyone else is already taken"]
]
with open('withoutquotes.csv', 'w', newline='') as file:
    writer = csv.writer(file, quoting=csv.QUOTE_NONE, delimiter=';') #The writer is configured with quoting=csv.QUOTE_NONE to specify that no quotes should be used around fields in the output.
    writer.writerows(row_list)

# %% [markdown]
# <b>Reader Output:</b><br>
# 1. The csv.reader object returns each row as a list of strings. This is consistent with how the reader works:
# 2. each row in the file is split into fields based on the specified delimiter (;), and the fields are returned as a list.
#  <br><b> Desired Output:</b>
# 3. To achieve the output format you specified (SN;Name;Quotes, etc.), you need to convert each list of fields into a single string with semicolons (;) separating the fields.
# 4. You can achieve this by using the join() method to join the fields in each list with a semicolon (;) and then print the resulting string.

# %%
with open('withoutquotes.csv', 'r', newline='') as file:
    reader = csv.reader(file, delimiter=';')
    for row in reader:
      
        print(row)
# Out:
# ['SN', 'Name', 'Quotes']
# ['1', 'Buddha', 'What we think we become']
# ['2', 'Mark Twain', 'Never regret anything that made you smile']
# ['3', 'Oscar Wilde', 'Be yourself everyone else is already taken']

# %%
with open('withoutquotes.csv', 'r', newline='') as file:
    reader = csv.reader(file, quoting=csv.QUOTE_NONE, delimiter=';')
    for row in reader:
        # Convert each row list to a string with semicolons separating fields
        print(';'.join(row))
#The join() method is called on the semicolon string (';'), which specifies that the strings in the list should be joined using a semicolon as the delimiter.
#The join() method takes the list of strings and concatenates them into a single string, with each element separated by the specified delimiter (;).
#The resulting string is '1;Buddha;What we think we become'.
# Out:
# SN;Name;Quotes
# 1;Buddha;What we think we become
# 2;Mark Twain;Never regret anything that made you smile
# 3;Oscar Wilde;Be yourself everyone else is already taken

# %% [markdown]
# ![image.png](attachment:d16bbaa4-28b1-4a41-9a70-695ab2321575.png)

# %%
#Writing CSV files with custom quoting character
import csv
row_list = [
    ["SN", "Name", "Quotes"],
    [1, "Buddha", "What we think we become"],
    [2, "Mark Twain", "Never regret anything that made you smile"],
    [3, "Oscar Wilde", "Be yourself everyone else is already taken"]
]
#Here, we can see that quotechar='*' parameter instructs the writer object to use * as quote for all non-numeric values.
with open('quotes_quotech.csv', 'w', newline='') as file:
    writer = csv.writer(file, quoting=csv.QUOTE_NONNUMERIC,
                        delimiter=';', quotechar='*') 
    writer.writerows(row_list)

# %%
with open('quotes_quotech.csv', 'r', newline='') as file:
    reader = csv.reader(file, delimiter=';')
    for row in reader:
        #print(row)
        print(';'.join(row))
# Out:
# *SN*;*Name*;*Quotes*
# 1;*Buddha*;*What we think we become*
# 2;*Mark Twain*;*Never regret anything that made you smile*
# 3;*Oscar Wilde*;*Be yourself everyone else is already taken*

# %% [markdown]
# ![image.png](attachment:c469166f-40a6-4077-9ce2-39c23a332cc6.png)

# %% [markdown]
# ![image.png](attachment:b99b3c96-34b7-4e55-80c6-69a6f916f25f.png)
# 1. While creating the writer object, we pass dialect='myDialect' to specify that the writer instance must use that particular dialect.
# 2. The advantage of using dialect is that it makes the program more modular. Notice that we can reuse myDialect to write other CSV files without having to re-specify the CSV format.

# %%
import csv
row_list = [
    ["ID", "Name", "Email"],
    [878, "Alfonso K. Hamby", "alfonsokhamby@rhyta.com"],
    [854, "Susanne Briard", "susannebriard@armyspy.com"],
    [833, "Katja Mauer", "kmauer@jadoop.com"]
]
#we can see that the csv.register_dialect() function is used to define a custom dialect. 
csv.register_dialect('farhanDialect',
                     delimiter='|',
                     quoting=csv.QUOTE_ALL)

with open('office.csv', 'w', newline='') as file:
    writer = csv.writer(file, dialect='farhanDialect')
    writer.writerows(row_list)

# %%
with open('office.csv', 'r', newline='') as file:
    reader = csv.reader(file, dialect='farhanDialect')
    for row in reader:
        print(row)
       # print('|'.join(row))
# Out:
# ['ID', 'Name', 'Email']
# ['878', 'Alfonso K. Hamby', 'alfonsokhamby@rhyta.com']
# ['854', 'Susanne Briard', 'susannebriard@armyspy.com']
# ['833', 'Katja Mauer', 'kmauer@jadoop.com']

# %%
#The CSV file has initial spaces, quotes around each entry, and uses a | delimiter.
#Instead of passing three individual formatting patterns, let's look at how to use dialects to read this file.

with open('office.csv', 'r', newline='') as file:
    reader = csv.reader(file, dialect='myDialect')
    for row in reader:
        print(row)
        #print('|'.join(row))
# Out:
# ['ID', 'Name', 'Email']
# ['A878', 'Alfonso K. Hamby', 'alfonsokhamby@rhyta.com']
# ['F854', 'Susanne Briard', 'susannebriard@armyspy.com']
# ['E833', 'Katja Mauer', 'kmauer@jadoop.com']

# %% [markdown]
# ![image.png](attachment:a7320d9d-1e62-4a8b-8f45-1e265dc772ed.png)
#
# <br>Then, the csv.reader() is used to read the file, which returns an iterable reader object.
#
# The reader object is then iterated using a for loop to print the contents of each row.

# %%
import csv
with open('innovators.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['SN', 'Name', 'Contribution']
# ['1', 'Linus Torvalds', 'Linux Kernel']
# ['2', 'Tim Berners-Lee', 'World Wide Web']
# ['3', 'Guido van Rossum', 'Python Programming']

# %% [markdown]
# ![image.png](attachment:e1615c51-eead-4395-9e4a-c4fc29c2beec.png)

# %%
#Example 2: Read CSV file Having Tab Delimiter
#As we can see, the optional parameter delimiter = '\t' helps specify the reader object that the CSV file we are reading from, has tabs as a delimiter.
import csv
with open('innovators-tab.csv', 'r') as file:
    reader = csv.reader(file, delimiter = '\t')
    for row in reader:
        print(row)
# Out:
# ['SN', 'Name', 'Contribution']
# ['1', 'Linus Torvalds', 'Linux Kernel']
# ['2', 'Tim Berners-Lee', 'World Wide Web']
# ['3', 'Guido van Rossum', 'Python Programming']

# %% [markdown]
# ![image.png](attachment:bf6cda81-51ba-43f6-a413-c8843d5fdb67.png)

# %%
#Read CSV files with initial spaces
import csv
with open('people.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, skipinitialspace=True) #This allows the reader object to know that the entries have initial whitespace. As a result, the initial spaces that were present after a delimiter is removed.
    for row in reader:
        print(row)
# Out:
# ['SN', 'Name', 'City']
# ['1', 'John', 'Washington']
# ['2', 'Eric', 'Los Angeles']
# ['3', 'Brad', 'Texas']

# %% [markdown]
# <b>CSV files with Custom Delimiters<b><br>
# By default, a comma is used as a delimiter in a CSV file. However, some CSV files can use delimiters other than a comma. Few popular ones are | and \t.
# <br>Suppose the innovators.csv file in Example 1 was using tab as a delimiter.
# <br>To read the file, we can pass an additional delimiter parameter to the csv.reader() function.
# <br>the optional parameter delimiter = '\t' helps specify the reader object that the CSV file we are reading from, has tabs as a delimiter.

# %%
import csv
with open('innovators.csv', 'r') as file:
    reader = csv.reader(file, delimiter = '\t')
    for row in reader:
        print(row)
# Out:
# ['SN,Name,Contribution']
# ['1,Linus Torvalds,Linux Kernel']
# ['2,Tim Berners-Lee,World Wide Web']
# ['3,Guido van Rossum,Python Programming']

# %% [markdown]
# ![image.png](attachment:ae47cf91-8bdd-4c08-938e-1d1a219d1bfd.png)
# <br>The writeheader() method is called on the writer object to write a header row to the CSV file.
# 1. The header row contains the field names specified in fieldnames (player_name and fide_rating).
# 2. This row is written as the first row in the CSV file.

# %%
#Python csv.DictWriter()
import csv

with open('students.csv', 'w', newline='') as file:
    heading_names = ['Student_name', 'CGPA']
    #A csv.DictWriter object is created using the file object as the source for writing data.
    writer = csv.DictWriter(file, fieldnames=heading_names) 

    writer.writeheader()
    writer.writerow({'Student_name': 'Farhan', 'CGPA': 3.8})
    writer.writerow({'Student_name': 'Iqrar', 'CGPA': 3.8})
    writer.writerow({'Student_name': 'Usman', 'CGPA': 3.8})

# %%
#Read CSV files with csv.DictReader()
#The objects of a csv.DictReader() class can be used to read a CSV file as a dictionary.
import csv
with open("students.csv", 'r') as file:
    csv_file = csv.DictReader(file)
    for row in csv_file:
        print(row)
        #print(dict(row))
# Out:
# {'Student_name': 'Farhan', 'CGPA': '3.8'}
# {'Student_name': 'Iqrar', 'CGPA': '3.8'}
# {'Student_name': 'Usman', 'CGPA': '3.8'}

# %%
# Specify the path to the output CSV file
#script that demonstrates how to create a CSV file that uses a comma followed by a space (", ") as a delimiter between 
#the columns S.No, name, and city:
csv_file_path = "people_delimeter_space.csv"

# Define the data to write to the CSV file
data = [
    [1, "John Doe", "New York"],
    [2, "Jane Smith", "Los Angeles"],
    [3, "Alice Brown", "Chicago"],
]

# Define the delimiter to be a comma followed by a space
delimiter = ", "

# Open the file in write mode
with open(csv_file_path, 'w') as file:
    header = ["S.No", "name", "city"]
# Join the header list using the delimiter and add a newline character at the end
    file.write(delimiter.join(header) + '\n')
    
    # Write the data rows
    for row in data:
        # Convert each element in the row to a string, join the row using the delimiter, and add a newline character at the end
        file.write(delimiter.join(map(str, row)) + '\n')

print(f"CSV file '{csv_file_path}' has been created with a delimiter '{delimiter}'.")
# Out:
# CSV file 'people_delimeter_space.csv' has been created with a delimiter ', '.

# %%
import csv
with open('people_delimeter_space.csv', 'r') as file:
    reader = csv.reader(file,quoting=csv.QUOTE_NONE, skipinitialspace=True)
    # Iterate over each row in the CSV file
    for row in reader:
        print(row)
        # Remove double quotes from each item in the row
        # Use list comprehension to strip double quotes from each item
        #cleaned_row = [item.strip('"') for item in row]
        
        # Print the cleaned row
        #print(cleaned_row)
# Out:
# ['S.No', 'name', 'city']
# ['1', 'John Doe', 'New York']
# ['2', 'Jane Smith', 'Los Angeles']
# ['3', 'Alice Brown', 'Chicago']

# %%
def check_csv_delimiter(file_path):
    # Define possible delimiters to check
    possible_delimiters = [',', ';', '\t', '|']
    
    # Read the first line of the CSV file
    with open(file_path, 'r') as file:
        first_line = file.readline()
    
    # Initialize a dictionary to count occurrences of each delimiter
    delimiter_count = {delimiter: first_line.count(delimiter) for delimiter in possible_delimiters}
    
    # Find the delimiter with the maximum count
    detected_delimiter = max(delimiter_count, key=delimiter_count.get)
    
    # Print the detected delimiter and its count in the first line
    print(f"Detected delimiter: '{detected_delimiter}' with count: {delimiter_count[detected_delimiter]}")
    
    return detected_delimiter

# Specify the path to the input CSV file
csv_file_path = "innovators.csv"

# Check the delimiter used by the input CSV file
detected_delimiter = check_csv_delimiter(csv_file_path)
# Out:
# Detected delimiter: ',' with count: 2
