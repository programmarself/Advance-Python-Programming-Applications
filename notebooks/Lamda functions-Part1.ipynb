# %% [markdown]
# Lambda functions are also known as anonymous functions. these functions are written in one line.They donot span multi-line.
# they are quite useful in some scenarios <br>
#  syntax of lamda functions:<br> lambda input: expression     <br>lambda is a keyword

# %% [markdown]
# <b>Python Lambda/Anonymous Function </b><br>
# In Python, a lambda function is a special type of function without the function name. For example,
#
# lambda : print('Hello World')
# Here, we have created a lambda function that prints 'Hello World'.

# %% [markdown]
# ![image.png](attachment:408ee0ad-a063-4457-871f-8ef881bbd65b.png)

# %%
greet = lambda : print('Eid ul fitr Mubarak')

#Here, we have defined a lambda function and assigned it to the variable named greet.

#To execute this lambda function, we need to call it. Here's how we can call the lambda function

# call the lambda
greet()

#The lambda function above simply prints the text 'Hello World'.

#Note: This lambda function doesn't have any argument.
# Out:
# Eid ul fitr Mubarak

# %% [markdown]
# <b>Python lambda Function with an Argument </b><br>
# Similar to normal functions, a lambda function can also accept arguments. For example,

# %%
# lambda that accepts one argument
greet_user = lambda name : print(f'eid mubarak, {name}')

# lambda call
greet_user('Naseer')

# Output: Hey there, Atif
#Here, we have passed a string value 'Atif' to our lambda function.

#Finally, the statement inside the lambda function is executed
# Out:
# eid mubarak, Naseer

# %%
def square(x):
    return x*x
    
square(5)
# Out:
# 25

# %%
print(type(square))
# Out:
# <class 'function'>

# %%
square = lambda x : x**3

# lambda call
square(5)
# Out:
# 125

# %%
print(type(square))
# Out:
# <class 'function'>

# %%
#create a lamda function that calcualte the square of the given input number
# Define a lambda function to square a number
square = lambda x: x ** 2

# Use the lambda function
result = square(5)  # Result: 16
print(result)
# Out:
# 25

# %%
lst= [2,4,5,6]
doublelst = lambda x: [i * 2 for i in lst]

# Use the lambda function
result = doublelst(lst)  # Result: 16
print(result)
# Out:
# [4, 8, 10, 12]

# %%
#create a lamda function that take two numbers as input and then calculate the sum of  numbers
s1=lambda a,b: a+b         # here whole lambda fuction is returned and referenced by x

s1(3,4)
# Out:
# 7

# %%
#create a lamda function that take a list of numbers as input and then calculate the sum of  numbers
lst=[2,4,5,6,7]

result= lambda x: sum(x)         # here whole lambda fuction is returned and referenced by resut

result(lst)
# Out:
# 24

# %%
print(type(result))
# Out:
# <class 'function'>

# %%
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(type(x))
#
# NameError: name 'x' is not defined

# %% [markdown]
# Difference between lamda function and normal function
# 1. lambda function has no return value, In fact, whole lambda function is returned. see above the type of x is a function.
# while function can return a value.
# 2. lambda function is written in a single line.
# 3.  lambda functions are not used for code reusibility while normal functions are used for code reusibility.
#     lambda functions are developed for one time use.
# 4. lambda function has no name while normal function has name like def square():
# why lambda functions are used>
# In normal scenarios, we use normal functions. lambda functions are used along with higher order functions.
# Higher order functions require another function as input peform their job. or higher order function is a function
# that is returning another function.
# Lambda functions are used alongside higher-order functions. Higher-order functions are functions that accept other functions as arguments to perform their tasks

# %% [markdown]
#  1. Return Value of a Lambda Function
# Always returns the result of the expression it evaluates.
# No need to write return — the expression’s value is returned implicitly
#
# 2. Return Value of a Regular Function
# You must use the return keyword explicitly to return a value.
#
# If you don’t use return, the function returns None by default.

# %% [markdown]
# Python is not just about writing functions that perform simple tasks. It empowers developers with a powerful feature called “higher-order functions.” These functions take other functions as arguments or return functions as results.
# A higher-order function is a function that can accept one or more functions as arguments or return a function as its result.
#
# A lambda function, also known as an anonymous function, is a small, unnamed function defined using the lambda keyword.
# It's a quick way to create small, throwaway functions for simple operations.
# Lambda functions are especially handy when you need a function for a short period and don't want to define a full def function.

# %% [markdown]
# ![image.png](attachment:362c9c84-dc76-486f-875b-f7abc7df0802.png)

# %% [markdown]
# 1. List Concatenation using +
# Creates a new list with elements from both lists.
#
# Original lists are not modified.
#
# Slower for very large lists due to the creation of a new list.

# %%
a = [1, 2]
b = [3, 4]

c = a + b  # c = [1, 2, 3, 4]
print(c)
print(a)   # a is still [1, 2]
# Out:
# [1, 2, 3, 4]
# [1, 2]

# %% [markdown]
# 2. List extend() Method
# Modifies the original list in place.
#
# Adds elements from another iterable (like a list) to the end of the list.
#
# More memory-efficient and generally faster than concatenation.

# %% [markdown]
# ![image.png](attachment:ac94a969-3f1c-428e-876d-2398896b931e.png)

# %%
# create a lambda function that check whether the first character of string is a or not
# lambda function can be used in a lot of scenarios
c= lambda x: x[0]=='a'

c('atif')
# Out:
# True

# %%
def square():
    print("hello")
s=square()
print(s)
# Out:
# hello
# None

# %%
lst1= [3,4,4,4]
lst2= [3,4,4,4]
result=lst1.extend(lst2)
print(result)
lst1
# Out:
# None
# [3, 4, 4, 4, 3, 4, 4, 4]

# %%
type('a')
# Out:
# str

# %%
# create a lambda function that check whether the first character of string is a or not
# lambda function can be used in a lot of scenarios
c= lambda x: type(x[0])==str

c('atif')
# Out:
# True

# %%
c('banana')
# Out:
# True

# %%
lst=[1,2]

# %%
c(lst)
# Out:
# False

# %%
# condition with lambda function, create a lambda function that check whether a given no. is odd or even
x= lambda n: "Even" if n% 2==0 else "Odd"
x(4)
# Out:
# 'Even'

# %%
x(5)
# Out:
# 'Odd'

# %%
# I want a  function that give me three outputs, 1st output should be the sum of even no's in list
# the second output should be the sum of odd numbers in list and third output should be sum of numbers, divisble by 3.
# I need three values from the function

def return_sum(lst):
    even_sum=0
    odd_sum=0
    div3_sum=0
    for i in lst:
        if i % 2==0:
           even_sum= even_sum +i
            
        if i % 2!=0:
           odd_sum= odd_sum+i
            
        if i % 3==0:
           div3_sum= div3_sum + i
    
    return (even_sum, odd_sum, div3_sum)


lst= [11,14, 21,23,56, 78,45, 29, 28]

even_sum, odd_sum, div3_sum= return_sum(lst)

print("sum of even no is ", even_sum)
print('sum of odd no is ', odd_sum)
print('sum of nos divisbile by 3 is', div3_sum)
# Out:
# sum of even no is  176
# sum of odd no is  129
# sum of nos divisbile by 3 is 144
