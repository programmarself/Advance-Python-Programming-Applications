# %% [markdown]
# ![image.png](attachment:a9a9df57-b5fb-46da-8629-d849432e6f2c.png)

# %% [markdown]
# 1. Everything in Python is an object, and every object belongs to a class. For instance, there may be many LCD objects,
# so a given LCD object might come from the LG class (company). Integers, lists, and tuples are objects, and these objects belong to specific classes.
# 2. From now on, variables and objects can be considered the same thing.
# 3. A class is a blueprint that defines a data type. In Python, defining a variable of a particular data type creates an object
# of that class.
# 4. There are many different data types in Python, each developed by someone. Developing a data type involves defining its class
# or blueprint, which describes how an object will behave or function.
# 5. The behavior of an object is determined by the data members and methods included in its class.
# 6. Creating a class requires more time, effort, and code than creating an object.
# 7. For example, when you create a list object, you have access to a lot of methods because these methods are already defined
# by the developer when creating the list class.
# 8. Class consist of 2 things
# data: Description about an ojbect (nouns)
# Function: behavior of an object (verb)
# Suppose you are building a class car;
# Data: No. of wheels, color, engine type, brand
# Functions: calculate mileage, calculate average speed, open air bag, show gps navigation

# %%
lst=[1,2,3,4]
a=2
s='hello'
v= 3+5j

# %%
a=2     # a is the intgers object, which belongs to class 'int'
print(type(a))
# Out:
# <class 'int'>

# %%
#
l=[1,2,3,4] # list object of class 'list'
print(type(l))
# Out:
# <class 'list'>

# %% [markdown]
# ![image.png](attachment:54f41e7d-a86d-4b18-95a4-334f35b18e29.png)

# %% [markdown]
# Here are three commonly used naming conventions for identifiers:
#
# 1. Pascal Case (a.k.a. Upper Camel Case):
# In Pascal case, each word in the identifier starts with an uppercase letter, and there are no underscores between words.
# Example: FirstName, TotalAmount, CalculateArea
# 2. Camel Case (a.k.a. Lower Camel Case):
# In camel case, the first word starts with a lowercase letter, and each subsequent word starts with an uppercase letter.
# Example: firstName, totalAmount, calculateArea
# 3. Snake Case:
# In snake case, all words are lowercase, and words are separated by underscores (_).
# Example: first_name, total_amount, calculate_area

# %%
#Class Basic Structure
class Car:  # class name should be in Pascal case
    color='Blue'   # data...data members should be in snake case
    model='Sports' # data 
def calculate_avg_speed(km, miles): # method names shoud be in snake case
        pass

# %% [markdown]
# <b>Diagrammaric Representation of Class</b>
# private members of class are dentoed by - sign while public members are dentoed by + sign. data members are usually private and are not accesible outside the class and methods are public and therefore accessile outside the class in the program
# ![image.png](attachment:9b338afd-efa6-4a2e-b54b-df3a573a1592.png)

# %% [markdown]
# # Class is the datatype and object is the instance of class
# # Object Examples
# car-------->Vitz              Vitz= Car()        object= classname()
# Sports----->Coupe             Coupe= Sports()
# Animals----->Camel             Camel=Animals()

# %% [markdown]
# 1. if list is a class, then why we create list object like this
# 2.  When you create a list using a literal expression like lst = [2, 3, 45, 6, 5], Python internally calls list() to create an object of the list class.
# 2. Python provides a feature, object literal, which provides an easy way to create ojects of built-in classes.
# 1. In Python, you often create objects of built-in classes (such as integers, lists, and dictionaries) using object literal or
# literal expressions, such as 42 for integers, [] for lists, and {} for dictionaries.
# 2. These object literals provide a straightforward and concise way to create instances of these built-in classes.
# 3. you can create list object like this as well,  lst= list(), syntax similar to the one discussed in above cell
# 4. string object; s= str()

# %%
lst= list([1,2])
lst
# Out:
# [1, 2]

# %%
lst1=[2,3,4,5]
lst1
# Out:
# [2, 3, 4, 5]

# %%
a= str("hello")
s
# Out:
# 'hello'

# %%
print(type('hello'))
# Out:
# <class 'str'>

# %%
name= str('Atif')
print(name)
# Out:
# Atif

# %%
l=list([2,3,4])
print(l)
# Out:
# [2, 3, 4]

# %%
s=str("hello")
print(s)
# Out:
# hello

# %%
l= list([2,3,4,5])
print(l)
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# We are developing Application/software of ATM using OOP. So we will need a representation/class of how customer behave
# when using ATM machine. For class, we would require data members, 1. account balance ( when we deposit money, balance will be updated),
# when we withdrawl, account balance will be deducted, similary, balance check is also related to account balance
# 2. ATM Pin, without this, we can do nothing on ATM
# Behaviors/Methods: create_pin(), deposit(), withdrawal(), check_bal()
# 3. Difference between Function vs Method
# 1. A method is a special function defined within a class that can be accessed and called by an object of that class.
# 2. A function, on the other hand, refers to a general function that exists outside of a class and
# can be used independently of class instances.
# 3. Functions can operate on different data types, such as lists, strings, and integers.
# 4. For example, len(l) is a general function that works with various iterable data types, while l.append(2) calls the
# append method, which is a special method defined within the list class and can be accessed only by list objects."
#
# extra
# Method is a special function defined inside class and can be accessed by object of that class
# Function refers to normal/general function which does not exist in any class, can be used any user, and can be applied on
# list, string and integers. for exmaple len(l) is a general function, while l.append(2), append is special method defined inside
# list class and can be accesed only by list object.

# %%
#In Python, the len() function is used to determine the length of an iterable or a collection, such as a list, string, or dictionary. 
#It is not used on integers directly because integers are not collections and do not have a length. 
#Therefore, calling len() on an integer will result in a TypeError:
num = 1234
length = len(num)  # This will raise a TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 #In Python, the len() function is used to determine the length of an iterable or a collection, such as a list, string, or dictionary.
#       2 #It is not used on integers directly because integers are not collections and do not have a length.
#       3 #Therefore, calling len() on an integer will result in a TypeError:
#       4 num = 1234
# ----> 5 length = len(num)  # This will raise a TypeError
#
# TypeError: object of type 'int' has no len()

# %%
#If you want to determine the length of  string representation of integer, you would first convert the integer to a string
#and then apply the len() function:
num = 1234
length = len(str(num))  # Convert the integer to a string and then determine the length
print(f"The length of {num} as a string is: {length}")
# Out:
# The length of 1234 as a string is: 4

# %% [markdown]
# 1. variables in python are declared and initialized in constructor
# 2. __init__ is a constructor,which is a special method defined in the class whose code is automatically exectued when u create an object of class. Constructor name is same as class name in Java and C++, however, in python, it will be __init__
# we can prove this see below

# %%
class Atm:
    def __init__(self): # constructor
         pass
    def menu(self):
        pass
        
obj= Atm()

# %% [markdown]
# 1. In Python, instance variables are variables that are defined within a class but outside of any method, typically in the class's constructor (__init__ method). Each instance of the class (each object) will have its own copy of these variables.
#
# 2. In the context of your Atm class, variables such as pin and balance are defined in the constructor (__init__ method). This means that when you create a new instance of the Atm class, each instance will have its own copy of pin and balance:

# %%
class Atm:
   def __init__(self):
       self.pin=""
       self.balance=0
       self.menu()
   def menu(self):
       user_input= int(input(""" 
                      Hello, How would you like to proceed?
                      1. Enter 1 to create pin
                      2. Enter 2 to deposit balance
                      3. Enter 3 to withdraw balance
                      4. Enter 4 to check balance
                      5. Enter 5 to exit
                      """))
       if user_input==1:
           self.create_pin()
           #print("pin created")
       elif user_input==2:
           self.deposit_balance()
           #print("deposit balance")
       elif user_input==3:
           self.withdraw()
            #print("withdraw balance")
       elif user_input==4:
           self.checkbalance()
           print("cehk balance")
       else:
           print("bye")
    
   def create_pin(self):
        self.pin=input("Enter your pin")
        print("pin created successfully")
        self.menu()
       
   def withdraw(self):
        tmp=input("Please Enter your pin")
        if (tmp==self.pin):
            amt= int(input("Please Enter the amount u want to withdraw"))
            if amt<self.balance:
                self.balance=self.balance - amt
                print("Withdrawl successfully")
        else:
            print("Invalid pin")
        self.menu()
   
   def deposit_balance(self):
        tmp=input("Please Enter your pin")
        if (tmp==self.pin):
            amt= int(input("Please Enter the amount u want to deposit"))
            self.balance=self.balance + amt
            print("Amount deposited successfully")
        else:
            print("Invalid pin")
        self.menu()
   def checkbalance(self):
        tmp=input("Please Enter your pin")
        if (tmp==self.pin):
            print(self.balance)
            
        else:
            print("Invalid pin")
        self.menu()

# %%
obj=Atm()
#obj.deposit_balance()
#obj.withdraw()
#obj.checkbalance()
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        1
# Enter your pin 1234
# pin created successfully
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        2
# Please Enter your pin 1234
# Please Enter the amount u want to deposit 5000
# Amount deposited successfully
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
# ...

# %%
class Atm:
    def __init__(self): # constructor
        self.pin=""
        self.balance=0
        self.menu()
        
    def menu(self):
       user_input= input(""" 
                      Hello, How would you like to proceed?
                      1. Enter 1 to create pin
                      2. Enter 2 to deposit balance
                      3. Enter 3 to withdraw balance
                      4. Enter 4 to check balance
                      5. Enter 5 to exit
                      """)
       if user_input=="1":
            self.create_pin()
       elif user_input=="2":
            self.deposit_balance()
       elif user_input=="3":
            self.withdraw_balance()
       elif user_input=="4":
            self.check_balance()
       else:
            print("good bye")
    def create_pin(self):
        self.pin= input("Enter your pin")
        print("pin set successfully")
        
    def deposit_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.pin):
            amt=int(input("Enter the amount you want to deposit"))
            self.balance=self.balance + amt
            print("Amount deposited Successfully")
        else:
            print("Invalid Pin")
            
    def withdraw_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.pin):
            amt=int(input("Enter the amount you want to withdraw"))
            if amt < self.balance:
                self.balance= self.balance - amt
                print("Amount withdrawl Successfully")
            else:
                print("Insufficient funds")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.pin):
            print(self.balance)
        else:
            print("Invalid Pin")

# %%
obj= Atm()
obj.deposit_balance()
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        1
# Enter your pin 1234
# pin set successfully
# Enter your pin 1234
# Enter the amount you want to deposit 3457
# Amount deposited Successfully

# %%
obj.check_balance()
# Out:
# Enter your pin 1234
# 3457

# %%
obj.withdraw_balance()
obj.check_balance()
# Out:
# Enter your pin 1234
# Enter the amount you want to withdraw 3000
# Amount withdrawl Successfully
# Enter your pin 1234
# 457

# %%
obj.balance
# Out:
# 457

# %%
obj.balance=0

# %%
obj.balance
# Out:
# 0

# %%
obj2= Atm()
obj2.deposit_balance()
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        1
# etnering
# Enter your pin 3456
# pin set successfully
# Enter your pin 3456
# Enter the amount you want to deposit 90000
# Amount deposited Successfully

# %%
obj2.check_balance()
# Out:
# Enter your pin 3456
# 90000

# %% [markdown]
# 1. now our code is well managed, all the backened logic  is written in class, now create objects and peform differnt
# jobs through them
# 1. Magic/dunder in Python are the special methods that start and end with the double underscores.
# 2. They are also called dunder methods. They are trigerred automatically
# 3. Objects can not call magic methods. Magic methods are pre-defined in Python, we can not create magic methods.
# 4. Magic methods are not meant to be invoked directly by you, but the invocation happens internally from the class
# on a certain action. For example, when you add two numbers using the + operator, internally, the __add__() method will be called.
# 5. Built-in classes in Python define many magic methods. __init__ constructor is called automatically when object is created.
# Use the dir() function to see the number of magic methods inherited by a class. For example, the following lists all the attributes and methods defined in the int class.

# %%
print(dir(int)) #For example, the following lists all the attributes and methods defined in the int class.
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %% [markdown]
# 1. when you do num+10, the + operator calls the __add__(10) method. You can also call num.__add__(5) directly
# which will give the same result. However, as mentioned before, magic methods are not meant to be called directly,
# 2. but internally, through some other methods or actions.

# %%
n=5+5
print(n)
# Out:
# 10

# %%
#the int class includes various magic methods surrounded by double underscores. 
#For example, the __add__ method is a magic method which gets called when we add two numbers using the + operator. 
#Consider the following example.
#Example: Dunder Method Copy
num1=10
num2=10
res = num1.__add__(num2) 
print(res)
# Out:
# 20

# %% [markdown]
# 1. "A constructor is a special magic method in Python that is automatically executed when an object is created. Its control is not in the hands of the user. When the application starts, the code inside the constructor runs. Typically, we use the constructor for configuration-related tasks that should not rely on user input, such as establishing an internet connection. For example, if an application requires an internet connection and you ask the user to click a 'Connect to the Internet' button, the app may not work if the user does not click the button. Therefore, the app should not rely on user action for critical tasks."
# 2.  "Code for connecting to a database or establishing GPS connectivity should be placed in the constructor if these are essential tasks that need to be executed as soon as the application starts."
# "We include configuration-related tasks or code in the application's constructor so that when the application opens, these tasks are executed automatically. This can include connecting to a database, the internet, hardware, or performing other configuration-related tasks. This approach ensures the application runs smoothly without requiring user interaction for essential tasks."
#
# Extra no need<br>
# 4. constructor is one of the magic methods whose control is not with user and is executed automatically. As the application open up, the code inside the constructor is executed. Generally, we do configuration related tasks in constructor, which u dont rely on user,  like connecting with internet, for instance, when application open, and u ask user to click on the button connect to the Internet, and he does not click the button then app will not work, so app should not rely on user.
# 5. code connecting to database, connecting to GPS should be placed in constructor
# 6. We put that configuration related task/code in the constructor of the applicaiton, so that when the application opens, the code faclilate the application to run without asking from user,like connectivity with database, internet or hardware or any configuration related task.

# %%
#self is the object with which u are curretly working with
#or self is a reference to the current instance(object) of the class that you are working with
# define a class
class Student:
    def __init__(self):
        self.name=""
        self.age= 0
        print(f"The address of the current object is {id(self)}") #The id function returns the memory address of the current object u are working with

# create object of class
std1 = Student()
#std2=Student()
## Print the memory address of the std1 object
print(f"Address of std1 oject is {id(std1)}")
# std1 itself is self
std1.age = 21
std1.name = "Hassan"
print(f"Name: {std1.name}, id: {std1.age} ")
# Out:
# The address of the current object is 3005734103968
# Address of std1 oject is 3005734103968
# Name: Hassan, id: 21

# %%
std2=Student()
## Print the memory address of the std1 object
print(f"Address of std2 oject is {id(std2)}")
# Out:
# The address of the current object is 3005734097056
# Address of std2 oject is 3005734097056

# %% [markdown]
# Why self is required in each method of clas
# fundamental concept in OOP: Class contains data and methods and both of them can be accessed by object
# of that class.
# Concept2: A method of a class not access data or method of the same class,but many situations will encounter where one method will require access to another method, just like init requires access to menu method, but how, becuase we need object of class, and object will come from self and self refers to current object that just called the method
#
# or
# Class Structure: In OOP, a class is a blueprint that defines data attributes (fields) and methods (functions) that operate on that data. Objects are instances of a class, and each object contains its own set of the class's data and methods.
# Self Reference: In Python, the first parameter of each method within a class is typically self, which is a reference to the instance (object) that is calling the method. By convention, it is always called self to make the code clear and readable.<br>
# Accessing Data and Methods: The self reference allows methods within a class to access both the data attributes and other methods of the class. This is essential for object-oriented design, as it allows for encapsulation and modularization.
# Method Interactions: As you mentioned, a method within a class may need to interact with another method of the same class. Since self refers to the current instance (object), methods can use self to call other methods of the same class. For example, in your statement, __init__ might need to call menu to initialize some part of the object; it can do so using self.menu().

# %% [markdown]
# Fractions can not be handled in python nor in any language, if u write 4/5, python will return 0.8
# Now we want to create a fraction datatype. then will create fraction object in python. data related to fraction object: numerator, denominator

# %%
4/5
# Out:
# 0.8

# %%
class Fraction:
    def __init__(self,n, d):
        self.nun= n
        self.den=d

# %%
fobj1= Fraction(4,5)
print(fobj1)  # object of type fraction, object is created, but we are not able to see it
print(type(fobj1))
# Out:
# ...
# <class '__main__.Fraction'>

# %%
#fobjec1 is just integers and string objects, you can peform anything with fobj1 now that u can perform
# with integer
l=[1,2,3,fobj1] # fobj1 is not seen because we did not specify how the object will look like
l               # and object specifications will be provided by the one who creates the class
# Out:
# [1, 2, 3, <__main__.Fraction at 0x2bbd3b69130>]

# %%
fobj2= Fraction(4,5)
print(fobj1)  # object of type fraction, object is created, but we are not able to see it
# i want to show fraction object like 4/5, here magic methods can assist, they are special methods
# which are not called by objects and are called automatically on given condition. one of the magic methods
# is the __str__(), which is called automatically, when u print the object or put object in print method

# %%
class Fraction:
    def __init__(self,n, d):
        self.nun= n
        self.den=d
        
    def __str__(self):
        return "hello"

# %%
fobj3= Fraction(4,5)
fobj4=Fraction(4,3)

print(fobj3)
print(fobj4)
# Out:
# hello
# hello

# %%
# but now i pass string formatting. we can now show how our object will look like
class Fraction:
    def __init__(self,n, d):
        self.num= n
        self.den=d
    def __str__(self):
        #return "{}/{}".format(self.num,self.den)
        return f'{self.num}/{self.den}'

# %%
fobj3= Fraction(4,5)
fobj4=Fraction(2,3)


print(fobj3)
print(fobj4)
# Out:
# 4/5
# 2/3

# %%
#If i try to add two fraction objects, fobj3 + fobj4, will it be done? No
#becuase you did not specify how to add two fraction objects
print(fobj3+fobj4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 #If i try to add two fraction objects, fobj3 + fobj4, will it be done? No
#       2 #becuase you did not specify how to add two fraction objects
# ----> 3 print(fobj3+fobj4)
#
# TypeError: unsupported operand type(s) for +: 'Fraction' and 'Fraction'

# %%
s1={3,4,5}
s2={4,5,6}
s1+s2
# whoever created the class, did not specify how to add two set objects
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 s1={3,4,5}
#       2 s2={4,5,6}
# ----> 3 s1+s2
#       4 # whoever created the class, did not specify how to add two set objects
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
# what if i want to add two fraction objects,here third magic method __add__() comes. __add__() is
# trigered/called automatically by python, when u try to add two objects (means when put + between objects)
# and the code inside the __add__() is executed.

# %% [markdown]
# ![image.png](attachment:98c32896-1b8a-4ddc-b70c-065ef4d3f788.png)
# 1. In fraction addition, numerator will be summ of cross multipication while denominator will be mutipication of two denominators

# %%
class Fraction:
    def __init__(self,n, d):
        self.num= n
        self.den=d
        
    def __add__(self, other):
        
        temp_num= self.num * other.den + other.num * self.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)

# %%
x= Fraction(4,5)
y=Fraction(4,3)
print(x)
print(y)
print(x + y)
#print(fobj3)
# Out:
# 4/5
# 4/3
# 32/15

# %%
# still the above code will not handle a-b, becos u did not define how to subtract two objects, here
# 3rd magic method __sub__ comes, which is automatically trigerred/called when u try to subtract two objects

class Fraction:
    def __init__(self,n, d):
        self.num= n
        self.den=d
        
    def __add__(self, other):
        temp_num= self.num * other.den + other.num * self.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)

    def __sub__(self, other):
        temp_num= self.num * other.den - other.num * self.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)

# %%
x= Fraction(4,5)
y=Fraction(4,3)
print(x)
print(y)
#print(x + y)
print(x-y)
# Out:
# 4/5
# 4/3
# -8/15

# %%
#3rd magic method __mul__ comes, which is automatically trigerred/called when u try to multiply two objects
class Fraction:
    def __init__(self,n, d):
        self.num= n
        self.den=d
        
    def __add__(self, other):
        temp_num= self.num * other.den + other.num * self.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)

    def __sub__(self, other):
        temp_num= self.num * other.den - other.num * self.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)
    
    def __mul__(self, other):
        temp_num= self.num * other.num
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)

# %%
x= Fraction(4,5)
y=Fraction(4,3)
print(x)
print(y)
#print(x + y)
print(x*y)
# Out:
# 4/5
# 4/3
# 16/15

# %%
#3rd magic method __truediv__ comes, which is automatically trigerred/called when u try to divide two objects
class Fraction:
    def __init__(self,n, d):
        self.num= n
        self.den=d
        
    def __add__(self, other):
        temp_num= self.num * other.den + other.num * self.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)

    def __sub__(self, other):
        temp_num= self.num * other.den - other.num * self.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)
    
    def __mul__(self, other):
        temp_num= self.num * other.den
        temp_den= self.den * other.den
        return "{}/{}".format(temp_num,temp_den)

    def __truediv__(self, other):
        temp_num= self.num * other.den
        temp_den= self.den * other.num
        return "{}/{}".format(temp_num,temp_den)
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)

# %%
x= Fraction(4,5)
y=Fraction(4,3)
print(x)
print(y)
print(x + y)
print(x - y)
print(x * y)
print(x/y)
# Out:
# 4/5
# 4/3
# 32/15
# -8/15
# 12/15
# 12/20

# %% [markdown]
# # Need for encapsulation
# # Private attributes
# # Getter and Setter methods
# # Class Diagrams
# Any varaible that is created in constructor is called instance variable because instance variable posseses
# a different value for each object for instance each customer should have a different pin and balance value.
# or instance variable is a kind of varaible which has a different value for different objects
# --------------
# when u create a class, it a good practice hide the data members of the class by putting double underscore infront of variable, if u want, you can also hide methods from other users by putting double underscore. The private data/method members will be accessible within class but not accessible outside class

# %%
class Atm:
    def __init__(self): # constructor
        self.pin=""
        self.balance=0
        self.menu()
        
    def menu(self):
       user_input= input(""" 
                      Hello, How would you like to proceed?
                      1. Enter 1 to create pin
                      2. Enter 2 to deposit balance
                      3. Enter 3 to withdraw balance
                      4. Enter 4 to check balance
                      5. Enter 5 to exit
                      """)
       if user_input=="1":
            self.create_pin()
       elif user_input=="2":
            self.deposit_balance()
       elif user_input=="3":
            self.withdraw_balance()
       elif user_input=="4":
            self.check_balance()
       else:
            print("good bye")
    def create_pin(self):
        self.pin= input("Enter your pin")
        print("pin set successfully")
        
    def deposit_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.pin):
            amt=int(input("Enter the amount you want to deposit"))
            self.balance=self.balance + amt
            print("Amount deposited Successfully")
        else:
            print("Invalid Pin")
            
    def withdraw_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.pin):
            amt=int(input("Enter the amount you want to withdraw"))
            if amt < self.balance:
                self.balance= self.balance - amt
                print("Amount withdrawl Successfully")
            else:
                print("Insufficient funds")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.pin):
            print(self.balance)
        else:
            print("Invalid Pin")

# %%
hbl= Atm()
hbl.balance='xyz'
hbl.deposit_balance()
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        1
# Enter your pin 1234
# pin set successfully
# Enter your pin 1234
# Enter the amount you want to deposit 444
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 hbl= Atm()
#       2 hbl.balance='xyz'
# ----> 3 hbl.deposit_balance()
#
# Cell In[26], line 34, in Atm.deposit_balance(self)
#      32 if (tmp==self.pin):
#      33     amt=int(input("Enter the amount you want to deposit"))
# ---> 34     self.balance=self.balance + amt
#      35     print("Amount deposited Successfully")
#      36 else:
#
# ...

# %% [markdown]
# # in the above code, issue is that object hbl can access all the members data members or methods since #they are public, junior pogrammar or any other may change the data members, change the pin, or assign string to balance variable
# #and lead the code to crash like the one above, however, its resposiblity of senior programmer to avoid changing the data members, solution is to rotect/hide the data members to avoid access from outside the class.
# # in order to hide the data members from outside class, put double underscore infront of data members

# %%
class Atm:
    def __init__(self): # constructor
        self.__pin=""
        self.__balance=0
        self.__menu()
        
    def __menu(self):
       user_input= input(""" 
                      Hello, How would you like to proceed?
                      1. Enter 1 to create pin
                      2. Enter 2 to deposit balance
                      3. Enter 3 to withdraw balance
                      4. Enter 4 to check balance
                      5. Enter 5 to exit
                      """)
       if user_input=="1":
            self.create_pin()
       elif user_input=="2":
            self.deposit_balance()
       elif user_input=="3":
            self.withdraw_balance()
       elif user_input=="4":
            self.check_balance()
       else:
            print("good bye")
    def create_pin(self):
        self.__pin= input("Enter your pin")
        print("pin set successfully")
        
    def deposit_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.__pin):
            amt=int(input("Enter the amount you want to deposit"))
            self.__balance=self.__balance + amt
            print("Amount deposited Successfully")
        else:
            print("Invalid Pin")
            
    def withdraw_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.__pin):
            amt=int(input("Enter the amount you want to withdraw"))
            if amt < self.__balance:
                self.__balance= self.__balance - amt
                print("Amount withdrawl Successfully")
            else:
                print("Insufficient funds")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        tmp= input("Enter your pin")
        if (tmp==self.__pin):
            print(self.__balance)
        else:
            print("Invalid Pin")

# %% [markdown]
# Suppose you have Atm class, When u put double underscore before variable, __pin, python interpreter internally convert it to _Atm__pin at the time of execution, and hence replaces each instance of __pin to _Atm__pin in the whole code.
# similary, __balance------> _Atm__balance, throughout the program,
# All the methods will now be using __Atm__pin, _Atm__balance data members internally
# hbl2.__balance='3333' # here the python interpreter creates a new variable, but this varaible will not effect the existing logic and this varialbe has  no use, since all the methods are using _Atm__balance
# and hence still our class data members are protected,

# %%
hbl2= Atm()
print(hbl2._Atm__balance)
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        5
# good bye
# 0

# %%
hbl2= Atm()
hbl2.__balance='3333' #
hbl2.deposit_balance()
hbl2.check_balance()
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        1
# Enter your pin 1234
# pin set successfully
# Enter your pin 1234
# Enter the amount you want to deposit 500
# Amount deposited Successfully
# Enter your pin 1234
# 500

# %% [markdown]
# hbl2= Atm()
# hbl2._Atm__balance='axx' # can access the hidden data member of class if required to access the private
# hbl2.deposit_balance()
# hbl2.check_balance()
#
# 1.Nothing in python is truly private, python leaves the choice/decision upto developer to access the private data members outside the class or not.
#
# 2. The reasons that Python allows access to private attributes outside of the class:
#
# 3. Flexibility: Python is designed to give developers freedom and trust them to make decisions about how to write their code. This includes the ability to access or modify private attributes if necessary. Python does not strictly enforce access control (as other languages like Java or C++ do) because it trusts developers to understand the potential consequences of accessing private attributes directly. This means that Python places the responsibility on the developer to use best practices and avoid directly accessing private attributes unless they have a good reason to do so.
# 4. Accessibility: Allowing access to private attributes can sometimes be helpful, particularly in complex or advanced situations such as debugging or working around limitations in libraries or frameworks. For instance, a developer might need to access private data or methods in a library to fix a bug or extend functionality that is not exposed through the public interface.
# 5. Name Mangling: Python uses a mechanism called name mangling for private attributes and methods that begin with double underscores (__). This mechanism prefixes the attribute or method name with the class name, effectively "mangling" the name and making it harder to access from outside the class. However, it does not prevent access entirely; it serves as a warning to developers that these are intended to be private and should not be accessed directly.
# 6. Code Readability: By not strictly enforcing privacy through access modifiers (public, private, protected), Python keeps its syntax simpler and the code more readable. This decision is in line with Python's philosophy of emphasizing simplicity and readability.
# 7. Encapsulation: Although Python encourages the use of encapsulation by providing private attributes and methods, it leaves the choice to developers to use them appropriately. Developers are expected to respect the encapsulation principle by using public interfaces and avoiding direct access to private attributes. This helps maintain clean and maintainable code.

# %% [markdown]
# #Access Modifiers in Python : Public, Private and Protected
# 1. Various object-oriented languages like C++, Java, Python control access modifications which are used to restrict access to the variables and methods of the class.
# 2. Most programming languages has three forms of access modifiers, which are Public, Protected and Private in a class.
# 3. Python uses ‘_’ symbol to determine the access control for a specific data member or a member function of a class.
# 4. Access specifiers in Python have an important role to play in securing data from unauthorized access and in preventing it from being exploited.
# 5. A Class in Python has three types of access modifiers:
#
# Public Access Modifier
# Protected Access Modifier
# Private Access Modifier
# <br><b>Public Access Modifier:</b>
# 1. The members of a class that are declared public are easily accessible from any part of the program. All data members and member functions of a class are public by default.<br>
# <b>Protected Access Modifier:</b>
# 1. The members of a class that are declared protected are only accessible to a class derived from it. Data members of a class are declared protected by adding a single underscore ‘_’ symbol before the data member of that class.
# <br><b>Private Access Modifier:</b>
# 1. The members of a class that are declared private are accessible within the class only, private access modifier is the most secure access modifier. Data members of a class are declared private by adding a double underscore ‘__’ symbol before the data member of that class

# %%
# program to illustrate public access modifier in a class

class Student:
	
	# constructor
	def __init__(self, name, age):
		
		# public data members 
		self.Name = name
		self.Age = age

	# public member function	 
	def displayAge(self):
		
		# accessing public data member
		print("Age: ", self.Age)

# creating object of the class
obj = Student("Hassan", 20)

# accessing public data member
print("Name: ", obj.Name)

# calling public member function of the class
obj.displayAge()

#In the above program, Name and Age are public data members and displayAge() method is a public member 
#function of the class Student. 
#These data members of the class Student can be accessed from anywhere in the program.
# Out:
# Name:  Hassan
# Age:  20

# %%
# super class
class Student:
    
    # protected data members
    _roll = None
    _branch = None
        
    # constructor
    def __init__(self, roll, branch): 
        self._roll = roll
        self._branch = branch
    
    # protected member function 
    def _displayRollAndBranch(self):
        # accessing protected data members
        print("Roll: ", self._roll)
        print("Branch: ", self._branch)

# derived class
class Ugradstudent(Student):

    # constructor 
    def __init__(self, name, roll, branch): 
        Student.__init__(self, roll, branch) 
        self._name = name
        
    # public member function 
    def displayDetails(self):
        # accessing protected data members of super class 
        print("Name: ", self._name) 
        
        # accessing protected member functions of super class 
        self._displayRollAndBranch()

# creating objects of the derived class     
obj = Ugradstudent("Majid", 12346, "Information Technology") 

# calling public member functions of the class
obj.displayDetails()
# Out:
# Name:  Majid
# Roll:  12346
# Branch:  Information Technology

# %%
# program to illustrate private access modifier in a class

class Student:
	
	# private members
	__name = None
	__roll = None
	__branch = None

	# constructor
	def __init__(self, name, roll, branch): 
		self.__name = name
		self.__roll = roll
		self.__branch = branch

	# private member function 
	def __displayDetails(self):
		
		# accessing private data members
		print("Name: ", self.__name)
		print("Roll: ", self.__roll)
		print("Branch: ", self.__branch)
	
	# public member function
	def accessPrivateFunction(self): 
			
		# accessing private member function
		self.__displayDetails() 

# creating object 
obj = Student("Farhan", 1706256, "Computer Science")

# calling public member function of the class
obj.accessPrivateFunction()
# Out:
# Name:  Farhan
# Roll:  1706256
# Branch:  Computer Science

# %% [markdown]
# 1. encapsulation in Python is achieved by keeping attributes and methods private, using name mangling to hide them from external access, and providing controlled access to data through public methods such as getters and setters. This helps protect the data and ensures it is used and modified according to the rules established by the class.
#
# <b> idea of Encapsulation: </b><br>
# 1. Do not allow your data members to be public or directly accessible outside
# the class because anyone can change the value of data members such hbl.balance='xyz', which is not desirable.
# 2. alternate solution is to first hide the data members with double underscore. then, if anyone needs the private data members, then access can be allowed through 2 methods, get() and set() methods. get() method will fetch the value while set method will set/update the values of private data members according to certain rules/logic established by programmar. means one can not use set method to change values of data members at his own choice. so we are protecting the data. so for every data member, we are creating two methods, get() and set(), and using these three, we will use the data members and keeping them protected. this is the whole idea behind encapsulation.
#
#     or
#    "Idea of Encapsulation:
#
# 1. Encapsulation is a core principle in object-oriented programming that involves bundling data and methods that operate on the data within a class, while restricting direct access to the data from outside the class.
#
# 2. Private Data Members: It is important to keep data members private (using double underscores in Python) to prevent direct access from outside the class. This helps maintain control over how data is accessed and modified, protecting the integrity of the data.
# Getter and Setter Methods: To access and modify private data members, use getter (get()) and setter (set()) methods. Getter methods fetch the value of the private data members, while setter methods set or update their values according to the rules and logic established by the programmer. This way, data cannot be changed arbitrarily from outside the class.For instance, you might want to validate data before setting it, or format it in a specific way when retrieving it.
#
# 4. Protection and Flexibility: By using getter and setter methods, you can protect data integrity and enforce encapsulation. This approach also provides flexibility for future changes, as the internal implementation of the data can be modified without affecting code that uses the getter and setter methods.
# Encapsulation helps maintain the reliability and security of the data within a class, ensuring that data is used and modified in a controlled and predictable manner."

# %%
class Atm:
    def __init__(self): # constructor
        self.__pin=0
        self.__balance=0
        self.__menu()
        
    def get_pin(self):
        return self.__pin

    def set_pin(self, new_pin):
        if type(new_pin)==int:
            self.__pin=new_pin
            print("pin changed sucessfully")
        else:
            print("Invalid pin")
        
    def __menu(self):
       user_input= input(""" 
                      Hello, How would you like to proceed?
                      1. Enter 1 to create pin
                      2. Enter 2 to deposit balance
                      3. Enter 3 to withdraw balance
                      4. Enter 4 to check balance
                      5. Enter 5 to exit
                      """)
       if user_input=="1":
            self.create_pin()
       elif user_input=="2":
            self.deposit_balance()
       elif user_input=="3":
            self.withdraw_balance()
       elif user_input=="4":
            self.check_balance()
       else:
            print("good bye")
    def create_pin(self):
        self.__pin= int(input("Enter your pin"))
        print("pin set successfully")
        
    def deposit_balance(self):
        tmp= int(input("Enter your pin"))
        if (tmp==self.__pin):
            amt=int(input("Enter the amount you want to deposit"))
            self.__balance=self.__balance + amt
            print("Amount deposited Successfully")
        else:
            print("Invalid Pin")
            
    def withdraw_balance(self):
        tmp= int(input("Enter your pin"))
        if (tmp==self.__pin):
            amt=int(input("Enter the amount you want to withdraw"))
            if amt < self.__balance:
                self.__balance= self.__balance - amt
                print("Amount withdrawl Successfully")
            else:
                print("Insufficient funds")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        tmp= int(input("Enter your pin"))
        if (tmp==self.__pin):
            print(self.__balance)
        else:
            print("Invalid Pin")

# %%
obj=Atm() # obj is not object, it is a reference variable and points to the memory address where the Atm object is stored. 
obj.get_pin()
obj.set_pin(5.6) # if you pass 5.6, self.__pin will be set/change to 5.6
obj.set_pin("xyzz")
obj.set_pin("3333")
obj.get_pin()
#initially, we hide the data members and then we created two methods: get and set methods to fetch the
# value and change the value, the above code change the value of private data member as he was directly doing when data member
#use to be public, and setting any value for pin may crash the code, so what is the use/benefit  of this function, 
#since we are updating the value of data member through function, so we can build logic and control how the 
#data should be modified and we can validate the data before setting it
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        1
# Enter your pin 1234
# pin set successfully
# Invalid pin
# Invalid pin
# Invalid pin
# 1234

# %%
obj=Atm()
obj.get_pin()
#obj.set_pin(5.6) # if you pass 5.6, self.__pin will be set/change to 5.6
obj.set_pin("1223")
obj.get_pin()
# Out:
#
#                       Hello, How would you like to proceed?
#                       1. Enter 1 to create pin
#                       2. Enter 2 to deposit balance
#                       3. Enter 3 to withdraw balance
#                       4. Enter 4 to check balance
#                       5. Enter 5 to exit
#                        1
# Enter your pin 1234
# pin set successfully
# pin changed
# '1223'

# %%
class Customer:
    def __init__(self, name):
        self.name=name

# %%
cust= Customer('Mehran')
print(cust.name)
# Out:
# Mehran

# %%
class Customer:
    def __init__(self, name, gender):
        self.name=name
        self.gender=gender
        
def greet(customer): # now customer and cust are referecing to same object
    if customer.gender=="Male":
        print("hello,",customer.name, " Sir")
    else:
        print("hello,",customer.name, " Ma'm")

# %%
cust= Customer("Essa","Male")
greet(cust) # passing object(by reference) as argument to function

cust= Customer("Mrs Essa","Female")
greet(cust)
# Out:
# hello, Essa  Sir
# hello, Mrs Essa  Ma'm

# %%
class Customer:
    def __init__(self, name, gender):
        self.name=name
        self.gender=gender
        
def greet(customer): # now customer and cust are referecing to same object
    if customer.gender=="Male":
        print("hello,",customer.name, " Sir")
    else:
        print("hello,",customer.name, " Ma'm")
    new_cust=Customer("Adil",25)  # function is returning object of type Customer
    return new_cust

# %%
cust= Customer("Fazal","Male")
greet(cust) # passing object(by reference) as argument to function
cust= Customer("fareda","Female")
cust=greet(cust)
print(cust.name)
# Out:
# hello, Fazal  Sir
# hello, fareda  Ma'm
# Adil

# %%
class Customer:
    def __init__(self, name):
        self.name=name
def greet(customer): # now customer and cust are referecing to same object
    print(id(customer))         #both cust and customer are pointing to the same memory address of the object

# %%
cust= Customer("Atif")
print(id(cust))
greet(cust) # passing object(by recust= Customer("fareda","Female")

#object behave in a same mannaer just like other datatypes int, string and list
# Out:
# 1373838975168
# 1373838975168

# %% [markdown]
# 1. Mutability Evidence: Since the memory address printed at the beginning and end of the function is the same,
# 2. it indicates that the object was edited in place without changing its memory location.
# 3. This proves that the customer object is mutable because its attributes can be modified without creating a new object.
# 4. Objects of class are mutable just like lists, dictionary and sets

# %%
class Customer:
    def __init__(self, name):
        self.name=name
        
def greet(customer): # now customer and cust are referecing to same object
    print(id(customer))         #both cust and customer are pointing to the same memory address of the object
    customer.name='Hammad' # this change in the object will cause the change in the original object as well
    print(customer.name)
    print(id(customer)) # if this id of object does not change after oject editing, this proves that customer object is mutalbe
    #you are editing object on the same memory address, and hence customer is mutable type

# %%
cust= Customer("Atif")
print(id(cust))
greet(cust) # passing object(by recust= Customer("fareda","Female")
print(cust.name)
# Out:
# 2649799457200
# 2649799457200
# Hammad
# 2649799457200
# Hammad

# %% [markdown]
# 1. You are passing the original list l1 directly to the function change_list.
# 2. This means that change_list receives the actual list object (l1) and any modifications made to the list inside the function will also be reflected in the original list l1.
# 3. This behavior demonstrates that the list is mutable because the function can modify the original list directly.

# %%
# prove that list is mutable datatypes mean changes in the list object are made in-place without changing its memory location
def change_list(l):
    print(id(l))
    l.append(5)
    print(id(l))

# %% [markdown]
# 1. You are passing a copy of the list l1 to the function change_list.
# 2. This copy is created using the slice notation (l1[:]), which creates a shallow copy of the list.
# 3. When you pass l1[:] to change_list, the function receives a new list object that contains the same elements as l1, but is independent of the original list.
# 3. Any modifications made to the list inside the function change_list will affect only the copy, not the original list l1.

# %%
def change_list(l):
    print("change list object before edit", id(l))
    l.append(5)
    print("change list object after edit",id(l))

l1= [2,13,4,3]
print(id(l1))
print(l1)
change_list(l1[:]) # here we sent a cloned list to avoid changes in the original list
print(id(l1))
# Out:
# 2649821151680
# [2, 13, 4, 3]
# change list object before edit 2649821201280
# change list object after edit 2649821201280
# 2649821151680

# %%
if you pass mutable object by reference, any change made to the object inside the function will also be 
reflected in the origninal object, while if you pass immutable object (tuples), any change made in the object will not
be reflected in the original object.

# %%
def change_tuple(t):
    print("befor edit", id(t))
    t=t + (6,7)
    print("After edit",id(t))

t1= (2,13,4,3)
print("before change tuple",id(t1))
print(t1)
change_tuple(t1) 
print("After change tuple",id(t1))
print(t1)
# Out:
# before change tuple 2649821378848
# (2, 13, 4, 3)
# befor edit 2649821378848
# After edit 2649820536384
# After change tuple 2649821378848
# (2, 13, 4, 3)

# %%
#Merges loops with objects
# sets can have immutable data types only so objects can not be items of sets.
class Customer:
    def __init__(self, name, age):
        self.name=name
        self.age=age
        
    def intro(self):
        print("My name is ",self.name," I am ",self.age)
        
cust1= Customer("hassan", 20)
cust2= Customer("Ali", 20)
cust3=cust= Customer("Hanif", 21)

lst= [cust1, cust2, cust3] # collection of objects
for i in lst: # can iterte via list of objects
    #print(i)
    #print(i.name, i.age)
    i.intro()
# Out:
# My name is  hassan  I am  20
# My name is  Ali  I am  20
# My name is  Hanif  I am  21

# %%
#Merges loops with objects

class Customer:
    major='CS'
    def __init__(self, name, age,add):
        self.name=name
        self.age=age
        self.address=add
    def intro(self):
        print("Name: ",self.name," Age: ",self.age, ' Address: ', self.address, ' Major:',self.major)
        
cust1= Customer("hassan", 20,'Pesh')
cust2= Customer("Ali", 20,'Karak')
cust3=cust= Customer("Hanif", 21,'swabi')

lst= [cust1, cust2, cust3] # collection of objects
for i in lst: # can iterte via list of objects
    #print(i)
    #print(i.name, i.age)
    i.intro()
# Out:
# Name:  hassan  Age:  20  Address:  Pesh  Major: CS
# Name:  Ali  Age:  20  Address:  Karak  Major: CS
# Name:  Hanif  Age:  21  Address:  swabi  Major: CS

# %%
#static varaibles/class variable4- defined in class outside constructor
# instance variables--inside constructor
class Product:
    total_products = 0  # Static variable to track total products
    
    def __init__(self, id, name, price, quantity):
        self.id = id
        self.name = name
        self.price = price
        self.quantity = quantity
        Product.total_products += 1  # Increment total_products when a new product is created
        
    
    def display(self):
        print(f"Product ID: {self.id}")
        print(f"Name: {self.name}")
        print(f"Price: ${self.price}")
        print(f"Quantity: {self.quantity}")
        print()

    @staticmethod
    def display_total_products():
        print(f"Total Products: {Product.total_products}")


# Now, let's demonstrate the usage of the static variable:

# Creating some products
product1 = Product(1, "Apple", 1.5, 100)
product2 = Product(2, "Banana", 0.75, 150)
product3 = Product(3, "Orange", 2.0, 80)

# Displaying total number of products
Product.display(product1)
Product.display_total_products()

# Adding another product
product4 = Product(4, "Grapes", 3.0, 120)

# Displaying total number of products again
#Product.display_total_products()
# Out:
# Product ID: 1
# Name: Apple
# Price: $1.5
# Quantity: 100
#
# Total Products: 3

# %% [markdown]
# 1. Instance variables and static variables are both types of variables in object-oriented programming, but they serve different purposes and have different scopes.
#
# Instance Variable:<br>
#
# 1. An instance variable is a variable that is defined inside a class and belongs to each instance (object) of that class individually.
# 2. Each object has its own copy of instance variables.
# 3. They are initialized inside the constructor (__init__ method) using the self keyword.
# 4. Instance variables hold data that are unique to each object.
# 5. They are accessed using the object (instance) of the class.
# 6. Changes to instance variables affect only the specific instance they belong to.
# Example: In a Person class, name and age might be instance variables because each person has a different name and age.
#
# <b>Static Variable:</b>
#
# 1. A static variable (also known as a class variable) is a variable that is associated with the class as a whole rather than with specific instances of the class.
# 2. There is only one copy of the static variable that is shared among all instances of the class.
# 3. Static variables are defined at the class level, outside of any method, usually at the beginning of the class definition.
# 4. They are accessed using the class name.
# 5. Static variables are used to store data that is common to all objects of the class.
# 6. Changes to static variables affect all instances of the class.
# Example: In a Car class, num_wheels might be a static variable because all cars typically have the same number of wheels.
# ![image.png](attachment:ac3d3113-2f62-47e5-b127-011434ad7421.png)

# %%
class Product:
    total_products = 0  # Static variable to track total products
    
    def __init__(self, id, name, price, quantity):
        self.id = id
        self.name = name
        self.price = price
        self.quantity = quantity
        Product.total_products += 1  # Increment total_products when a new product is created
    
    def display(self):
        print(f"Product ID: {self.id}")
        print(f"Name: {self.name}")
        print(f"Price: ${self.price}")
        print(f"Quantity: {self.quantity}")
        print()

    @staticmethod
    def display_total_products():
        print(f"Total Products: {Product.total_products}")

class Inventory:
    def __init__(self):
        self.products = []
        
        self.menu()  # Call menu method when Inventory object is created
    
    def menu(self):
        print("Menu:")
        print("1. Press 1 to add product")
        print("2. Press 2 to search product")
        print("3. Press 3 to display inventory")
        choice = input("Enter your choice: ")
        
        if choice == "1":
            self.add_product()
        elif choice == "2":
            self.search_product_by_id()
        elif choice == "3":
            self.display_inventory()
        else:
            print("Invalid choice!")
        #self.menu()  # Display menu again if choice is invalid
    
    def add_product(self):
        n = eval(input("Enter number of products u want to add "))
        for i in range(n):
            id = eval(input("Enter product id "))
            name = input("Enter product name ")
            price = eval(input("Enter product price "))
            quanity = int(input("Enter product qunatity "))
            product1 = Product(id, name, price, quanity)
            self.products.append(product1)
        self.menu()
    
    def search_product_by_id(self):
        search_id = int(input("Enter product id that you want to search "))
        
        for product in self.products:
            if product.id == search_id:
                #return product
                print(f"Product with ID {search_id} found:")
                product.display()
            else:
                print(f"Product with ID {search_id} not found.")
        self.menu()
        #return None
    
    def display_inventory(self):
        print("Inventory:")
        
        for product in self.products:
            product.display()
        print(f"Total products are {Product.display_total_products()}")
        self.menu()
# Creating some products
#product1 = Product(1, "Apple", 1.5, 100)
#product2 = Product(2, "Banana", 0.75, 150)
#product3 = Product(3, "Orange", 2.0, 80)

# Creating an inventory
inventory = Inventory()

# Adding products to the inventory
#inventory.add_product(product1)
#inventory.add_product(product2)
#inventory.add_product(product3)

# Displaying the inventory
#inventory.display_inventory()

# Searching for a product by ID
#search_id = 2
#found_product = inventory.search_product_by_id(search_id)
#if found_product:
    #print(f"Product with ID {search_id} found:")
   # found_product.display()
#else:
    #print(f"Product with ID {search_id} not found.")
# Out:
# Menu:
# 1. Press 1 to add product
# 2. Press 2 to search product
# 3. Press 3 to display inventory
# Enter your choice:  1
# Enter number of products u want to add  2

# %%
class Student:
    sno=1
    program='Computer Science'
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.id=Student.sno  # use object to access the instance variable, here self refers to the object
        Student.sno=Student.sno+1  # use class name to access the static/class variable,
        
    
    # Getter methods
    def get_id(self):
        return self.id
    
    def get_name(self):
        return self.name
    
    def get_age(self):
        return self.age

    def get_Program():
        return Student.program
    
    # Setter methods
    def set_id(self, id):
        self.id = id
 
    def set_name(self, name):
        self.name = name
    
    def set_age(self, age):
        self.age = age

# Example usage:
student1 = Student("Ali", 20)
student2 = Student("hassan", 21)
student3 = Student("kareem", 24)
print(student1.id)
print(student2.id)
print(student3.id)
print(student1.sno) # Acess static variable using object
print(student2.sno)
print(student3.sno)
print(Student.sno) # Access static variable using class name
lst=[student1, student2, student3]
# Using getter methods to access attributes
for std in lst:
    print("ID:", std.get_id())
    print("Name:", std.get_name())
    print("Age:", std.get_age())
    print("Program:", Student.get_Program())
    print("-----------------------------------")

# Using setter methods to modify attributes
#student1.set_age(21)
#print("Updated Age:", student1.get_age())
# Out:
# 1
# 2
# 3
# 4
# 4
# 4
# 4
# ID: 1
# Name: Ali
# Age: 20
# Program: Computer Science
# -----------------------------------
# ID: 2
# Name: hassan
# Age: 21
# Program: Computer Science
# -----------------------------------
# ID: 3
# Name: kareem
# Age: 24
# Program: Computer Science
# -----------------------------------

# %%
class Student:
    sno=1
    program='Computer Science'
    def __init__(self, id, name, age):
        self.name = name
        self.age = age
        self.id=Student.sno  # use object to access the instance variable, here self refers to the object
        Student.sno=Student.sno+1  # use class name to access the static/class variable,
        
    
    # Getter methods
    def get_id(self):
        return self.id
    
    def get_name(self):
        return self.name
    
    def get_age(self):
        return self.age

    def get_Program():
        return Student.program
    
    # Setter methods
    def set_id(self, id):
        self.id = id
 
    def set_name(self, name):
        self.name = name
    
    def set_age(self, age):
        self.age = age

# Example usage:
Student.sno="dddd"  # if junior program assignn string, code will crash, solution is to make sno as private
student1 = Student(1, "Ali", 20)
student2 = Student(2, "hassan", 21)
student3 = Student(1, "kareem", 24)


# Using setter methods to modify attributes
#student1.set_age(21)
#print("Updated Age:", student1.get_age())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 36
#      34 # Example usage:
#      35 Student.sno="dddd"  # if junior program assignn string, code will crash, solution is to make sno as private
# ---> 36 student1 = Student(1, "Ali", 20)
#      37 student2 = Student(2, "hassan", 21)
#      38 student3 = Student(1, "kareem", 24)
#
# Cell In[14], line 8, in Student.__init__(self, id, name, age)
#       6 self.age = age
#       7 self.id=Student.sno  # use object to access the instance variable, here self refers to the object
# ----> 8 Student.sno=Student.sno+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
class Student:
    __sno=1
    __program='Computer Science'
    def __init__(self,name, age):
        self.name = name
        self.age = age
        self.id=Student.__sno  # use object to access the instance variable, here self refers to the object
        Student.__sno=Student.__sno+1  # use class name to access the static/class variable,
        
    
    # Getter methods
    def get_id(self):
        return self.id
    
    def get_name(self):
        return self.name
    
    def get_age(self):
        return self.age
   
    @staticmethod  # this keyword signifies that the method is static, and can be accessed without object, so self is not passed
    def get_SNo():
        return Student.__sno
    
    @staticmethod  # this keyword signifies that the method is static, and can be accessed without object, so self is not passed
    def get_Program():
        return Student.__program
    
    # Setter methods
    def set_id(self, id):
        self.id = id
 
    def set_name(self, name):
        self.name = name
    
    def set_age(self, age):
        self.age = age
   
    @staticmethod  # this keyword signifies that the method is static, and can be accessed without object, so self is not passed
    def set_Program(prg): # static method deals wiht static data members
        if type(prg)==str:
            Student.__program=prg
        else:
            print("invalid value")
    @staticmethod  # this keyword signifies that the method is static, and can be accessed without object, so self is not passed
    def set_SNo(sno1):
        if type(sno1)==int:
            Student.__sno=sno1
        else:
            print("invalid value")

# %%
#Student.sno="dddd"  # if junior program assignn string, code will crash, solution is to make sno as private
student1 = Student("Miraj", 20)
student2 = Student("hassan", 21)
student3 = Student("kareem", 24)
#Student.set_SNo(4)
Student.get_SNo()
# Out:
# 4

# %%
Student.set_Program(222)
# Out:
# invalid value

# %%
Student.set_Program('SE')
Student.get_Program()
# Out:
# 'SE'

# %% [markdown]
# 1. Two Relationships between classes in Python: Aggregation and Inheritance
# 2. Aggregation represents a 'Has-a' relationship, while inheritance signifies an 'Is-a' relationship.
# 3. In the context of classes, the relationship between the customer and address classes exemplifies aggregation, where a customer 'has' an address.
# 4. For instance, a car 'is a' vehicle, and a smartphone 'is a' product. Inheritance allows a car class to automatically inherit all the features of a vehicle class, illustrating the 'is-a' relationship."
#
# Extra
# 1. 2 Relationships between classes: Aggregation and Inheritance
# 2. Aggregation is Has-a relationship, and inheritance is is-a relationship
# 3.  The relationship between customer and address classes is aggregation, customer has address
# 4. Car is a vehicle, smartphone is a product, car inherits all features of vehicle automatically

# %%
class Customer:
    def __init__(self, name, gender, address):
        self.name=name
        self.gender=gender
        self.address=address

    def edit_profile(self, name,new_city, new_postalcode, new_state):
        self.name=name
        self.address.change_address(new_city, new_postalcode, new_state)

class Address:
     def __init__(self, city, postalcode, state):
        self.city=city
        self.postalcode=postalcode
        self.state=state

     def change_address(self,new_city, new_postalcode, new_state):
        self.city=new_city
        self.postalcode=new_postalcode
        self.state=new_state

# %%
addres= Address("Peshawar", 2500, "KPK")
cust1= Customer("Asif","male",addres )
print(cust1.name)
print(cust1.address.city)
print(cust1.address.postalcode)
print(cust1.address.state)
#print(cust1.edit_profile("Fazal Khan", ""))
# Out:
# Asif
# Peshawar
# 2500
# KPK

# %%
cust1.edit_profile("Fazal Khan","Topi","24460","KP")
print(cust1.name)
print(cust1.address.city)
print(cust1.address.postalcode)
print(cust1.address.state)
# Out:
# Fazal Khan
# Topi
# 24460
# KP

# %%
# Using vars()
for attribute, value in vars(cust1).items():
    print(attribute, ":", value)
# Out:
# name : Asif
# gender : male
# address : <__main__.Address object at 0x000001E0F31810D0>

# %%
# Using __dict__
for attribute, value in cust1.__dict__.items():
    print(attribute, ":", value)
# Out:
# name : Asif
# gender : male
# address : <__main__.Address object at 0x000001E0F31810D0>

# %% [markdown]
# 1. if hasattr(value, '__dict__'), It checks if the value object has a __dict__ attribute,
# which suggests that it's an instance of a user-defined class
# 2. If it does, the code assumes that value is an object instance and proceeds to loop over its attributes.
# 3. If it doesn't have a __dict__ attribute, it treats value as a non-object attribute and prints its value directly.

# %%
# Function to check if the attribute is an object instance and loop over its attributes
def print_attributes(obj):
    for attribute, value in vars(obj).items():
        if hasattr(value, '__dict__'):  # Check if the attribute is an object instance
            print(attribute + ":")
            for sub_attribute, sub_value in vars(value).items():
                print("\t" + sub_attribute + ":", sub_value)
        else:
            print(attribute + ":", value)

# Looping over attributes of the customer object
print("Customer's Attributes:")
print_attributes(cust1)
# Out:
# Customer's Attributes:
# name: Asif
# gender: male
# address:
# 	city: Peshawar
# 	postalcode: 2500
# 	state: KPK

# %% [markdown]
# 1. Inheritance--society level and biological level--property of your father is inherited to childern, biological: facial or other features are inherited to childrern. for exmaple, develpoing udemy type app, two users, students and instructors. build 2 classes.
# 2. Student class with methods: login(), registration(), enroll coursers, reviews()
# 3. Instructor classs methods:login(), registration(), create coursers, Answer-to-questions
# bad programming, if u repeat the same code that u already writte, philosphy of writing good code: principle:do not repeat yourself
# 4. here u can apply concept of inheritance, by creating a user class with common methods, and derive student and instructor classes from user class.
# 5. with the help of inheritance, the children classes can inherit all data members, constructor and allmethods from parent class. only private data members can not be inherited.
# 6. biggest advantage of inheritance epecially in big applications is code reusbility, which will save time saving, code conise and optimze and code will perform better

# %% [markdown]
# 1. Code Reusability: Inheritance allows you to create a new class that is based on an existing class, inheriting its attributes and methods. This promotes code reuse as you can leverage existing code without having to rewrite it.
#
# 2. Time Savings: By reusing existing code through inheritance, developers can save time that would otherwise be spent writing and debugging new code for similar functionality.
#
# 3. Conciseness: Inheritance promotes concise code by allowing you to define common behavior and attributes in a parent class, reducing the need for redundant code in subclasses.
#
# 3. Optimization: Inheritance can help optimize code structure by organizing related classes hierarchically. This makes it easier to understand and maintain the codebase, leading to better overall performance.
#
# 4. Performance: In some cases, inheritance can lead to better performance because it allows for the reuse of optimized code from parent classes.

# %%
# Student is a sub-class of user class and object of student class can access all the members of parent
#class due to inheritance.
# Student class is inheriting from user class.
#Reverse inheritance is not posssible,that is user class object can not access members of student class, if u do so, code will crash
class user:
    def login(self):
        print("login done")

    def register(self):
        print("registration done")
        
class Student (user):
    def enroll (self):
        print("enrollment done")

    def review(self):
        print("review done")

class Instructor (user):
    def create_course (self):
        print("Courses created")

    def Answer_questions(self):
        print("Ans done")

# %%
std= Student()
std.enroll()
std.login()
std.register()
std.review()
# Out:
# enrollment done
# login done
# registration done
# review done

# %%
user1=user() # reverse inheritance is not possible
user1.login()
user1.register()
user1.enroll()
user1.review()
# Out:
# login done
# registration done
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 user1.login()
#       3 user1.register()
# ----> 4 user1.enroll()
#       5 user1.review()
#
# AttributeError: 'user' object has no attribute 'enroll'

# %%
# Inheriting constructor
# concept, if class B is inheriting from Class A, while creating object of class B, 
#if the constructor of class B does not exist, then class A constructor will be callled


class Phone:
    def __init__(self,price, brand, camera):
        self.price=price
        self.brand=brand
        self.camera=camera
        
class SmartPhone(Phone): # Smartphone is inheriting from phone
    pass

phone=SmartPhone(3000, "Samsung", 14)
print(phone.brand)
print(phone.price)
# Out:
# Samsung
# 3000

# %%
# Attempting to inherit private data members
# Object of child class can inherit only public members of parent class
class Phone:
    def __init__(self,price, brand, camera):
        self.price=price
        self.__brand=brand # private data member
        self.camera=camera
class SmartPhone(Phone): # Smartphone is inheriting from phone
    pass

phone=SmartPhone(3000, "Samsung", 14)
print(phone.__brand)  # code will crash here
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 12
#       9     pass
#      11 phone=SmartPhone(3000, "Samsung", 14)
# ---> 12 print(phone.__brand)  # code will crash here
#
# AttributeError: 'SmartPhone' object has no attribute '__brand'

# %%
# 3 concepts comes under polymorphism
# method overriding-->polymorphism
# method overloading-->polymorphism
# operator overloading-->polymorphism

# %%
#polymorphism
class Phone:
    def __init__(self,price, brand, camera):
        self.price=price
        self.__brand=brand # private data member
        self.camera=camera
    def buy (self):
        print("buying a phone")
        
class SmartPhone(Phone): # Smartphone is inheriting from phone
    def buy (self):
        print("buying a smart phone")
        
phone=SmartPhone(3000, "Samsung", 14)
phone.buy()   #method overrding
p1=Phone(400, "Phone", 14)
p1.buy()
# Out:
# buying a smart phone
# buying a phone

# %% [markdown]
# 1. we see the object of the subclass can access the method of the superclass.
# 2. However, what if the same method is present in both the superclass and subclass?
# 3. In this case, the method in the subclass overrides the method in the superclass. This concept is known as method overriding in Python.
#
# or
# 1. Method overriding is an ability of any object-oriented programming language that allows a subclass or child class to provide a specific implementation of a method that is already provided by one of its super-classes or parent classes.
# 2. When a method in a subclass has the same name, same parameters or signature and same return type(or sub-type) as a method in its super-class, then the method in the subclass is said to override the method in the super-class.
# 3. The version of a method that is executed will be determined by the object that is used to invoke it. If an object of a parent class is used to invoke the method, then the version in the parent class will be executed,
# 4. but if an object of the subclass is used to invoke the method, then the version in the child class will be executed.
# 5. In other words, it is the type of the object being referred to (not the type of the reference variable) that determines which version of an  method will be executed.

# %%
Analogy of method overriding from real world
1.Imagine a company where there's a standard procedure for submitting reports. 
2.Each department has its own guidelines for report formatting, but all reports ultimately need to follow a company-wide template.
3. For example, the Marketing department might override the report submission method to include specific metrics related to campaign performance, 
4. while the Finance department might include financial forecasts in their reports. 
4. Despite these variations, all reports still adhere to the general company template, ensuring consistency across the organization.

# %%
class parent:
    def __init__(self, num):
        self.num=num
    
    def get_num(self):
        return self.num
        
class child(parent):
    def show(self):
        print("child class")

c1= child(200) # python will call child class constructor, if not found, then parent class constructor is called
c1.get_num()
# Out:
# 200

# %%
class parent:
    def __init__(self, num):
        self.num=num
    def get_num(self):
        return self.num
        
class child(parent):
    def show(self):
        print("child class")

c1= child(100) # python will call child class constructor, if not found, then parent class constructor is called
c1.get_num()
# Out:
# 100

# %%
#both parent and child classes have constructor
class parent:
    def __init__(self, num):
        self.__num=num         #self.num is not initialized since parent class constructor is not invoked
        
    def get_num(self):
        print("hello")
        return self.__num   
        
class child(parent):   # if no constrcutor in child class, then parent class constructor is automatically invoked,
    def __init__(self, val, num): # but if child class has its own constructor, then parent class constructor will not be invoked
        self.__val= val          
        self.__num=num
        
    def get_val(self):
        return self.__val
    
      
    def show(self):
        print("child class")

son= child(100,200) # object of child clas
print("Child val", son.get_val())
print("parent num",son.get_num())
# Out:
# Child val 100
# hello
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 24
#      22 son= child(100,200) # object of child clas
#      23 print("Child val", son.get_val())
# ---> 24 print("parent num",son.get_num())
#
# Cell In[16], line 8, in parent.get_num(self)
#       6 def get_num(self):
#       7     print("hello")
# ----> 8     return self.__num
#
# AttributeError: 'child' object has no attribute '_parent__num'

# %%
class parent:
    def __init__(self, num):
        self.__num=num         #self.num is not initialized since parent class constructor is not invoked
        
    def get_num(self):
        return self.__num   
        
class child(parent):   # if no constrcutor in child class, then parent class constructor is automatically invoked,
    def __init__(self, val, num): # but if child class has its own constructor, then parent class constructor will not be invoked
        super().__init__(num)  # Explicitly calling the parent class constructor
        self.__val= val          
               
    def get_val(self):
        return self.__val
        
    def show(self):
        print("child class")

son= child(100,200) # object of child clas
print("parent num",son.get_num())
print("Child val", son.get_val())
# Out:
# parent num 200
# Child val 100

# %%
class A:
    def __init__(self):
            self.var1=100
    
    def display1(self, var1):
        print("Class A", self.var1)

class B(A):
    def display2(self, var1):
        print("Class B", self.var1)

obj= B()
obj.display1(200)
# Out:
# Class A 100

# %%
class Phone:
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.price=price
        self.__brand=brand # private data member
        self.camera=camera
    
    def buy (self):
        print("buying a phone")
        
class SmartPhone(Phone): # Smartphone is inheriting from phone
    def buy (self):
        print("buying a smart phone")
        super().buy()        
# super keyword is only used to call parent class methods/constructor, 
#it can not be used to access Parent class data member
 #super keyword can not be used outside class 

phone=SmartPhone(3000, "Samsung", 14)
phone.buy()   #method overrding
# Out:
# inside parent class constructor
# buying a smart phone
# buying a phone

# %%
#both parent and child have constructurs, and we used super in the child class to call the parent class

#constructor
class Phone:
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
   
    def buy (self):
        print("buying a phone")

# smart coding, half initialization in my constrcutor and then delegate things to 
#(or half initailization) parent class constructor
# resuing the coding of parent class constructor rather than writing the same in 
#child class constructor

class SmartPhone(Phone): # Smartphone is inheriting from phone
    def __init__(self,price, brand, camera, os, ram): # initialized smartphone specific attributes here
        print("inside child class constructor")
        # call the parent call constructor to initialized the attributes common to all phones
        super().__init__(price, brand, camera) 
        self.os=os
        self.ram=ram 
        
    def buy (self):
        print("buying a smart phone")
        super().buy()        # super keyword is only used to call parent class methods/constructor, it can not be used to access PC data member
                             #super keyword can not be used outside class 

phone=SmartPhone(3000, "Samsung", 14, "Adroid",2)
print(phone.os) 
print(phone.brand)
print(phone.camera)
# Out:
# inside child class constructor
# inside parent class constructor
# Adroid
# Samsung
# 14

# %%
class parent:
    def __init__(self, num):
        self.__num=num         #self.num is initialized in the parent class constructor         
    def get_num(self):
        return self.__num   
        
class child(parent):   
    def __init__(self, val, num): 
       
        super().__init__(num) # the statement having super keyword should be your first statment in the child class constructor
        self.__val= val
               
    def get_val(self):
        return self.__val
        
    def show(self):
        print("child class")

son= child(100,200) # object of child clas
print("Son num",son.get_num())
print("SOn val", son.get_val())
# Out:
# Son num 200
# SOn val 100

# %%
class parent:
    def __init__(self):
        self.num=100         
        
    def get_num(self):
        return self.num   
        
class child(parent):   
    def __init__(self):
       
        super().__init__() # the statement having super keyword should be your first statment in the child class constructor
        self.val= 200

    # can we access the parent class attribute in the child class using self, yes
    def show(self):  # self contains reference to child object, and child object can access the data member of parent class
        print(self.num)
        print(self.val)
        
son= child() # object of child clas
son.show()     # son and self above are same, since son can access num data from outside class, so self can access it from within clas
# Out:
# 100
# 200

# %%
class parent:
    def __init__(self):
        self.__num=100         
        
    def show(self):
        print("Parent:", self.__num)
        
class child(parent):   
    def __init__(self):
       
        super().__init__() # the statement having super keyword should be your first statment in the child class constructor
        self.__val= 200

    # can we access the parent class attribute in the child class using self, yes
    def show(self):  # self contains reference to child object, and child object can access the data member of parent class
        
        print("Child:", self.__val)
        
P=parent()  #parent object
P.show()
son= child() # object of child clas
son.show()    # Due to method overriding, child calss show method will be called
# Out:
# Parent: 100
# Child: 200

# %% [markdown]
# ![image.png](attachment:1855e1b2-4954-4672-b91c-2e9518788cd7.png)

# %% [markdown]
# There are five types of inheritance in python
# 1. Single Level: single child, single parent, a child inherit from the parent class
# 2. Multi-level: child, papa, grandpapa, child inherits the properties of papa as well as grandpapa. and papa inherits the properties of grandpapa.
# 3. heirarchical: Two child, single parent, two child inherit the properites of single parent
# 4. Multiple: one child, two parents(mother, father): a child inherit properties from two parent classes
# 5. hybrid: single level-->multiple inheritance-->heirarchical inheritance

# %%
# Example of single level inheritance

class Phone:
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
        
    def buy (self):
        print("buying a phone")

# smart coding, half initialization in my constrcutor and then delegate things to (or half initailization) parent class constructor
# resuing the coding of parent class constructor rather than writing the same in child class constructor

class SmartPhone(Phone): # Smartphone is inheriting from phone
    pass

SmartPhone(3000, "Samsung", "14px").buy()
# Out:
# inside parent class constructor
# buying a phone

# %% [markdown]
# In Python, if a child class (like SmartPhone) does not define its own __init__ constructor, then it inherits the constructor of its nearest parent.

# %%
# Example of Mutli level inheritance
class product:
    def review(self):
        print("product customer review")
        
class Phone(product):
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
    def buy (self):
        print("buying a phone")

# smart coding, half initialization in my constrcutor and then delegate things to (or half initailization) 
# inparent class constructor, resuing the coding of parent class constructor rather than writing the 
#same in child class constructor

class SmartPhone(Phone): # Smartphone is inheriting features from phone as well inheriting properties from product
    pass

s=SmartPhone(3000, "Samsung", "14px")
s.buy()     # child class accessing mehtod of parent class
s.review()   # child class accessing mehtod of product class
p= Phone(4000, "Apple", "13px")
p.buy()            #object of parent class accesing its own method buy()
p.review()         #object of parent class accesing mehtod of parent class product
# Out:
# inside parent class constructor
# buying a phone
# product customer review
# inside parent class constructor
# buying a phone
# product customer review

# %%
# Example of heirarchical inheritance
        
class Phone:
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
        
    def buy (self):
        print("buying a phone")

class SmartPhone(Phone): # Smartphone is inheriting features/attributes from phone
    pass

class Feature(Phone): # Feature is inheriting features from phone
    pass

s=SmartPhone(3000, "Samsung", "14px")
s.buy()
# Out:
# inside parent class constructor
# buying a phone

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("inside parent class constructor")
        self.__price = price
        self.brand = brand  # private data member
        self.camera = camera

    def buy(self):
        print("buying a phone")


class SmartPhone(Phone):  # Smartphone is inheriting features/attributes from phone
    def __init__(self, price, brand, camera, os, ram):
        super().__init__(price, brand, camera)  # Call the parent class constructor
        self.os = os
        self.ram = ram


class Feature(Phone):  # Feature is inheriting features from phone
     def __init__(self, f1, f2):
        self.f1 = f1
        self.f2 = f2
#he Feature class does not have its own __init__ method. Instead, it inherits the __init__ method 
#from its parent class, Phone. 
#Therefore, when you create an object of the Feature class and provide values such as 2000, "Nokia", 
#and "10px",they are passed to the constructor of the parent class, Phone, through inheritance.

s=SmartPhone(3000, "Samsung", "14px","Android","4GB")
s.buy()
F=Feature("finger print sensor", "16GB")  # Creating an object of Feature class

F.buy()  # Calling the buy method
# Out:
# inside parent class constructor
# buying a phone
# buying a phone

# %%
# Example of Mutliple inheritance

class Product:
    def review(self):
        print("product customer review")
        
class Phone:
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
    def buy (self):
        print("buying a phone")

#you can inherit from any number of classes
class SmartPhone(Phone, Product): # Smartphone is inheriting features from phone as well inheriting properties from product, 
    pass

s=SmartPhone(3000, "Samsung", "14px")
s.buy()     # child class accessing mehtod of parent class
s.review()   # child class accessing mehtod of product class
# Out:
# inside parent class constructor
# buying a phone
# product customer review

# %%
# Example of Mutliple inheritance
# Classes product and Phone both have constructors
class Product:
    def __init__(self):
        print("Inside the Product class constructor")
    def review(self):
        print("product customer review")
        
class Phone:
    def __init__(self,price, brand, camera):
        print("inside Phone class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
    def buy (self):
        print("buying a phone")

#you can inherit from any number of classes
# Smartphone inherits construcors from both Phone and Product constructors, 
#now which constructor will be invoked, 
# since phone class appears first, so its constructor will be invoked, if no constructor in phone, 
#then product class constructor will be invoked

class SmartPhone(Phone, Product): # Smartphone is inheriting features from phone as well inheriting properties from product, 
    pass

s=SmartPhone(3000, "Samsung", "14px")
s.buy()     # child class accessing mehtod of parent class
s.review()   # child class accessing mehtod of product class
# Out:
# inside Phone class constructor
# buying a phone
# product customer review

# %%
# Example of Mutliple inheritance
# only Class product has constructor

class Product:
    def __init__(self):
        print("Inside the Product class constructor")
    def review(self):
        print("product customer review")
        
class Phone:
    #def __init__(self,price, brand, camera):
     #   print("inside Phone class constructor")
      #  self.__price=price
      #  self.brand=brand # private data member
       # self.camera=camera
    def buy (self):
        print("buying a phone")

#you can inherit from any number of classes
# Smartphone inherits construcors from both Phone and Product constructors, now which constructor will be invoked, 
# since phone class appears first, so its constructor will be invoked, if no constructor in phone, then product class constructor will be invoked
class SmartPhone(Phone, Product): # Smartphone is inheriting features from phone as well inheriting properties from product, 
    pass

#s=SmartPhone(3000, "Samsung", "14px")
s=SmartPhone()
s.buy()     # child class accessing mehtod of parent class
s.review()   # child class accessing mehtod of product class
# Out:
# Inside the Product class constructor
# buying a phone
# product customer review

# %%
# Example of Mutliple inheritance
# Both Classes product and Phone have no constructors
class Product:
    
    def review(self):
        print("product customer review")
        
class Phone:
    
    def buy (self):
        print("buying a phone")

class SmartPhone(Phone, Product): # Smartphone is inheriting features from phone as well inheriting properties from product, 
    pass

#s=SmartPhone(3000, "Samsung", "14px")
s=SmartPhone()
s.buy()     # child class accessing mehtod of parent class
s.review()   # child class accessing mehtod of product class
# Out:
# buying a phone
# product customer review

# %%
# Method Resolution order, if both product and phone have buy methods and child class Smartphone 
#inherit from both classes
# then which buy method will be called, in this conflicting situation, the decision will be made 
#based on the order in which classes are written
# if Phone class is writen first, then its buy() will be called otherwise product class buy()

class Product:
    def review(self):
        print("product customer review")
        
    def buy (self):
        print("Product buy method")
        
class Phone:
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
        
    def buy (self):
        print("buying a phone")


#you can inherit from any number of classes
class SmartPhone(Phone, Product): # Smartphone is inheriting features from phone as well inheriting properties from product, 
    pass

s=SmartPhone(3000, "Samsung", "14px")
s.buy()
# Out:
# inside parent class constructor
# buying a phone

# %%
class Product:
    def review(self):
        print("product customer review")
        
    def buy (self):
        print("Product buy method")
        
class Phone:
    def __init__(self,price, brand, camera):
        print("inside parent class constructor")
        self.__price=price
        self.brand=brand # private data member
        self.camera=camera
        
    def buy (self):
        print("buying a phone")


#you can inherit from any number of classes
class SmartPhone(Product, Phone): # Smartphone is inheriting features from phone as well inheriting properties from product, 
    pass

s=SmartPhone(3000, "Samsung", "14px")
s.buy()
# Out:
# inside parent class constructor
# Product buy method

# %%
# Multi-level Inheritance
class A:
    def m1(self):
        return 20
        
class B(A):
    def m1(self):
        return 30
        
    def m2(self):
        return 40

class C(B):
    def m2(self):
        return 20

obj1= A()
obj2= B()
obj3= C()
print(obj1.m1() + obj3.m1() + obj3.m2()) # 20+30+20
# Out:
# 70

# %%
# Multi-level Inheritance
class A:
    def m1(self):
        return 20
        
class B(A):
    def m1(self):
        val= super().m1() + 30
        return val
        
class C(B):
    def m1(self):
       val = self.m1() + 20 # infinite recursion , obj3.m1()=self.m1()
       return val
        

obj3= C()
obj3.m1()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[27], line 18
#      14        return val
#      17 obj3= C()
# ---> 18 obj3.m1()
#
# Cell In[27], line 13, in C.m1(self)
#      12 def m1(self):
# ---> 13    val = self.m1() + 20 # infinite recursion , obj3.m1()=self.m1()
#      14    return val
#
# Cell In[27], line 13, in C.m1(self)
#      12 def m1(self):
# ---> 13    val = self.m1() + 20 # infinite recursion , obj3.m1()=self.m1()
#      14    return val
#
#     [... skipping similar frames: C.m1 at line 13 (2974 times)]
#
# Cell In[27], line 13, in C.m1(self)
#      12 def m1(self):
# ---> 13    val = self.m1() + 20 # infinite recursion , obj3.m1()=self.m1()
#      14    return val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# 1. In Python, polymorphism can indeed be achieved through method overriding, method overloading, and operator overloading,
# 2. Method overloading is achieved by providing different inputs to same method to induce different behavior
# 3. So, while you can indeed create methods in Python that behave differently based on the inputs provided,
# 4. it's not achieved through traditional method overloading as seen in languages like Java. Instead, it's more about writing flexible methods that can handle different inputs gracefully.

# %%
# this code will work perfectly well in java but not work in python
# In python, we can not define multiple methods with same, providing them different input 
#to behave differnently
# this code will work in java, here the second area method has overriddent the first method
# Tecnically, method overlaoding does not work in python
class Geometry:
    def area(self, radius):
        return 3.14*radius * radius

    def area(self, l, b):
        return l*b

obj= Geometry()
obj.area(3)
# Out:
# 9

# %%
obj.area(3,4)
# Out:
# 12

# %% [markdown]
# 1. Technically speaking, traditional method overloading, as seen in languages like Java or C++, where you can define multiple methods with the same name but different parameter lists, does not exist in Python.
#
# 2. In Python, if you define multiple methods with the same name, the last method definition will overwrite any previous ones with the same name, and only the latest method definition will be retained.
#
# 3. However, you can achieve similar functionality by using default argument values or variable-length argument lists (*args and **kwargs). This allows you to define a single method that can handle different numbers or types of arguments gracefully.
# 4. OR this allow u to define a single method that will behave differently on different inputs.
# 5.  While this is not traditional method overloading, it serves a similar purpose in allowing you to create flexible methods that behave differently based on the inputs provided.
#
# 6. So, in summary, while traditional method overloading does not exist in Python, you can achieve similar behavior using other techniques available in the language.

# %%
#method overloading acheived through default argument
class Geometry:
    
    def area(self, l, b=0):
        if b==0:
            print("Area of circle", 3.14*l*l)
        else:
            print("Area of Rectangle", l*b)

obj= Geometry()
obj.area(3)
obj.area(3,3)
# Out:
# Area of circle 28.259999999999998
# Area of Rectangle 9

# %% [markdown]
# 1. {}: This is a placeholder for the value that will be inserted into the formatted string.
# 2. : This indicates the start of the format specification.
# 3. .2: This specifies the precision of the floating-point number, i.e., the number of decimal places to display. In this case, it's 2, indicating that 4. we want to display the number with two decimal places.
# 5. f: This specifies that the placeholder should be filled with a floating-point number.
# So, "{:.2f}" is a format string that tells Python to format the inserted value as a floating-point number with two decimal places.

# %%
class Geometry:
    def area(self, *args):
        
        if len(args) == 1:
            if isinstance(args[0], (float)) and args[0] > 0: #isinstance(args[0], (int, float)) is a Python built-in function used to check if a variable belongs to a specific type or any of a set of types.
                # Circle: area = π * r^2
                radius = args[0]
                # Format the area to two decimal places
                #formatted_circle_area = "{:.2f}".format(circle_area)
                #{:.2}
                
                print("Area of circle:", "{:.3f}".format(3.14 * radius * radius))
            else:
                # Square: area = side * side
                side = args[0]
                print("Area of Square:", side * side)
        
        elif len(args) == 2:
            # Rectangle: area = length * breadth
            length, breadth = args
            
            print("Area of Rectangle:", length * breadth)
       
        #elif len(args) == 3:
            # Triangle: area = (base * height) / 2
           # base, height = args[:2]
            #print("Area of Triangle:", (base * height) / 2)
        else:
            print("Invalid number of arguments provided")

obj = Geometry()
obj.area(3.0)  # Area of circle
obj.area(4, 5)  # Area of Rectangle
#obj.area(3, 4, 5)  # Area of Triangle
obj.area(4)  # Area of Square
# Out:
# Area of circle: 28.260
# Area of Rectangle: 20
# Area of Square: 16

# %% [markdown]
# 1. In Python, we can change the way operators work for user-defined types.
# 2. For example, the + operator will perform arithmetic addition on two numbers, merge two lists, or concatenate two strings.
# 3. This feature in Python that allows the same operator to have different meaning according to the context is called operator overloading.
